# %%
import tweepy
import pandas as pd

# Claves de la app (las obtienes en developer.x.com)
api_key = "b6kglbl5HV57Pne0FsJF093dR"
api_secret = "E7SLODvuKqZazmBeEc9JlP5Qnc5VgYkcuHwomcGYvQhPuM9hGZ"
access_token = "1988649363288297472-PJcov7FaKIXdGzcHUOWsYvzUmk2Qmi"
access_secret = "brVO46wcVk9EvPvoSBeMZBaWCmh7KzTyNgWxxnLJTrWgZ"
bearer_token = "AAAAAAAAAAAAAAAAAAAAANeq5QEAAAAAgaAEOWsbHdNEk%2F%2BcVIIsQXplK1c%3DPM9QbU4Cc3otvRoLnjHx17QvTc4BukKE6yW2YxhsSv9QdItx7U"

client = tweepy.Client(bearer_token=bearer_token)

query = '("manifestación" OR "protesta" OR "bloqueo" OR "paro") AND ("Uruapan" OR "alcalde Uruapan" OR "presidente municipal Uruapan" OR "Héctor") AND "Michoacán" lang:es -is:retweet place_country:MX'
tweets = client.search_recent_tweets(query=query, max_results=100)

data = []
for tweet in tweets.data:
    data.append(tweet.text)

df = pd.DataFrame(data, columns=["texto"])
df.to_csv("corpus_twitter.csv", index=False)

print("✅ Corpus guardado en corpus_twitter.csv")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Cell In[7], line 14
#      11 client = tweepy.Client(bearer_token=bearer_token)
#      13 query = '("manifestación" OR "protesta" OR "bloqueo" OR "paro") AND ("Uruapan" OR "alcalde Uruapan" OR "presidente municipal Uruapan" OR "Héctor") AND "Michoacán" lang:es -is:retweet place_country:MX'
# ---> 14 tweets = client.search_recent_tweets(query=query, max_results=50)
#      16 data = []
#      17 for tweet in tweets.data:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:1276, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1184 """search_recent_tweets( \
#    1185     query, *, end_time=None, expansions=None, max_results=None, \
#    1186     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1273 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1274 """
#    1275 params["query"] = query
# -> 1276 return self._make_request(
#    1277     "GET", "/2/tweets/search/recent", params=params,
#    1278     endpoint_parameters=(
#    1279         "end_time", "expansions", "max_results", "media.fields",
#    1280         "next_token", "place.fields", "poll.fields", "query",
#    1281         "since_id", "sort_order", "start_time", "tweet.fields",
#    1282         "until_id", "user.fields"
#    1283     ), data_type=Tweet, user_auth=user_auth
#    1284 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:115, in BaseClient.request(self, method, route, params, json, user_auth)
#     113         return self.request(method, route, params, json, user_auth)
#     114     else:
# --> 115         raise TooManyRequests(response)
#     116 if response.status_code >= 500:
#     117     raise TwitterServerError(response)
#
# TooManyRequests: 429 Too Many Requests
# Too Many Requests

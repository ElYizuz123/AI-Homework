# %%
import os
from PIL import Image
from pathlib import Path

# Configuración
DATASET_PATH = "C:/Datasets/DatasetsAi_Resized/DatasetsAi_Resized" 
OUTPUT_PATH = "C:/Datasets/DatasetsAi_Resized/DatasetsAi_Resized_96x96"  # Carpeta de salida
TARGET_SIZE = (96, 96) 

def resize_images(input_dir, output_dir, target_size):
    """
    Redimensiona todas las imágenes en las subcarpetas del directorio de entrada.
    
    Args:
        input_dir: Directorio con las carpetas de clases
        output_dir: Directorio donde se guardarán las imágenes redimensionadas
        target_size: Tupla (ancho, alto) del tamaño deseado
    """
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    # Crear directorio de salida si no existe
    output_path.mkdir(parents=True, exist_ok=True)
    
    # Contador de imágenes procesadas
    total_images = 0
    errors = 0
    
    # Extensiones de imagen válidas
    valid_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff'}
    
    # Iterar sobre cada carpeta (clase) en el dataset
    for class_folder in input_path.iterdir():
        if not class_folder.is_dir():
            continue
        
        print(f"\nProcesando carpeta: {class_folder.name}")
        
        # Crear carpeta de salida para esta clase
        output_class_folder = output_path / class_folder.name
        output_class_folder.mkdir(parents=True, exist_ok=True)
        
        # Procesar cada imagen en la carpeta
        images_in_folder = 0
        for img_file in class_folder.iterdir():
            # Verificar si es un archivo de imagen
            if img_file.suffix.lower() not in valid_extensions:
                continue
            
            try:
                # Abrir imagen
                img = Image.open(img_file)
                
                # Convertir a RGB si es necesario (para imágenes PNG con transparencia, etc.)
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                
                # Redimensionar imagen con resize directo
                img_resized = img.resize(target_size, Image.LANCZOS)
                
                # Guardar imagen redimensionada
                output_file = output_class_folder / img_file.name
                img_resized.save(output_file, quality=95)
                
                images_in_folder += 1
                total_images += 1
                
                if images_in_folder % 50 == 0:
                    print(f"  Procesadas {images_in_folder} imágenes...")
                    
            except Exception as e:
                print(f"  Error procesando {img_file.name}: {str(e)}")
                errors += 1
        
        print(f"  ✓ Completado: {images_in_folder} imágenes procesadas")
    
    print(f"\n{'='*50}")
    print(f"Proceso completado:")
    print(f"  Total de imágenes procesadas: {total_images}")
    print(f"  Errores encontrados: {errors}")
    print(f"  Tamaño final: {target_size}")
    print(f"  Dataset guardado en: {output_path}")
    print(f"{'='*50}")

# Ejecutar el resize
resize_images(DATASET_PATH, OUTPUT_PATH, TARGET_SIZE)

print("\n¡Listo! Ahora puedes usar el dataset redimensionado para entrenar tu CNN.")
# Out:
# Procesando carpeta: Gato
#   Procesadas 50 imágenes...
#   Procesadas 100 imágenes...
#   Procesadas 150 imágenes...
#   Procesadas 200 imágenes...
#   Procesadas 250 imágenes...
#   Procesadas 300 imágenes...
#   Procesadas 350 imágenes...
#   Procesadas 400 imágenes...
#   Procesadas 450 imágenes...
#   Procesadas 500 imágenes...
#   Procesadas 550 imágenes...
#   Procesadas 600 imágenes...
#   Procesadas 650 imágenes...
#   Procesadas 700 imágenes...
#   Procesadas 750 imágenes...
#   Procesadas 800 imágenes...
#   Procesadas 850 imágenes...
#   Procesadas 900 imágenes...
#   Procesadas 950 imágenes...
#   Procesadas 1000 imágenes...
#   Procesadas 1050 imágenes...
#   Procesadas 1100 imágenes...
#   Procesadas 1150 imágenes...
#   Procesadas 1200 imágenes...
#   Procesadas 1250 imágenes...
#   Procesadas 1300 imágenes...
#   Procesadas 1350 imágenes...
#   Procesadas 1400 imágenes...
#   Procesadas 1450 imágenes...
#   Procesadas 1500 imágenes...
#   Procesadas 1550 imágenes...
#   Procesadas 1600 imágenes...
#   Procesadas 1650 imágenes...
#   Procesadas 1700 imágenes...
#   Procesadas 1750 imágenes...
#   Procesadas 1800 imágenes...
#   Procesadas 1850 imágenes...
#   Procesadas 1900 imágenes...
#   Procesadas 1950 imágenes...
#   Procesadas 2000 imágenes...
#   Procesadas 2050 imágenes...
#   Procesadas 2100 imágenes...
#   Procesadas 2150 imágenes...
#   Procesadas 2200 imágenes...
#   Procesadas 2250 imágenes...
#   Procesadas 2300 imágenes...
#   Procesadas 2350 imágenes...
#   Procesadas 2400 imágenes...
#   Procesadas 2450 imágenes...
#   Procesadas 2500 imágenes...
#   Procesadas 2550 imágenes...
#   Procesadas 2600 imágenes...
#   Procesadas 2650 imágenes...
#   Procesadas 2700 imágenes...
#   Procesadas 2750 imágenes...
#   Procesadas 2800 imágenes...
#   Procesadas 2850 imágenes...
#   Procesadas 2900 imágenes...
#   Procesadas 2950 imágenes...
#   Procesadas 3000 imágenes...
#   Procesadas 3050 imágenes...
#   Procesadas 3100 imágenes...
#   Procesadas 3150 imágenes...
#   Procesadas 3200 imágenes...
#   Procesadas 3250 imágenes...
#   Procesadas 3300 imágenes...
#   Procesadas 3350 imágenes...
#   Procesadas 3400 imágenes...
#   Procesadas 3450 imágenes...
#   Procesadas 3500 imágenes...
#   Procesadas 3550 imágenes...
#   Procesadas 3600 imágenes...
#   Procesadas 3650 imágenes...
#   Procesadas 3700 imágenes...
#   Procesadas 3750 imágenes...
#   Procesadas 3800 imágenes...
#   Procesadas 3850 imágenes...
#   Procesadas 3900 imágenes...
#   Procesadas 3950 imágenes...
#   Procesadas 4000 imágenes...
#   Procesadas 4050 imágenes...
#   Procesadas 4100 imágenes...
#   Procesadas 4150 imágenes...
#   Procesadas 4200 imágenes...
#   Procesadas 4250 imágenes...
#   Procesadas 4300 imágenes...
#   Procesadas 4350 imágenes...
#   Procesadas 4400 imágenes...
#   Procesadas 4450 imágenes...
#   Procesadas 4500 imágenes...
#   Procesadas 4550 imágenes...
#   Procesadas 4600 imágenes...
#   Procesadas 4650 imágenes...
#   Procesadas 4700 imágenes...
#   Procesadas 4750 imágenes...
#   Procesadas 4800 imágenes...
#   Procesadas 4850 imágenes...
#   Procesadas 4900 imágenes...
#   Procesadas 4950 imágenes...
#   Procesadas 5000 imágenes...
#   Procesadas 5050 imágenes...
#   Procesadas 5100 imágenes...
#   Procesadas 5150 imágenes...
#   Procesadas 5200 imágenes...
#   Procesadas 5250 imágenes...
#   Procesadas 5300 imágenes...
#   Procesadas 5350 imágenes...
#   Procesadas 5400 imágenes...
#   Procesadas 5450 imágenes...
#   Procesadas 5500 imágenes...
#   Procesadas 5550 imágenes...
#   Procesadas 5600 imágenes...
#   Procesadas 5650 imágenes...
#   Procesadas 5700 imágenes...
#   Procesadas 5750 imágenes...
#   Procesadas 5800 imágenes...
#   Procesadas 5850 imágenes...
#   Procesadas 5900 imágenes...
#   Procesadas 5950 imágenes...
#   Procesadas 6000 imágenes...
#   Procesadas 6050 imágenes...
#   Procesadas 6100 imágenes...
#   Procesadas 6150 imágenes...
#   Procesadas 6200 imágenes...
#   Procesadas 6250 imágenes...
#   Procesadas 6300 imágenes...
#   Procesadas 6350 imágenes...
#   Procesadas 6400 imágenes...
#   Procesadas 6450 imágenes...
#   Procesadas 6500 imágenes...
#   Procesadas 6550 imágenes...
#   Procesadas 6600 imágenes...
#   Procesadas 6650 imágenes...
#   Procesadas 6700 imágenes...
#   Procesadas 6750 imágenes...
#   Procesadas 6800 imágenes...
#   Procesadas 6850 imágenes...
#   Procesadas 6900 imágenes...
#   Procesadas 6950 imágenes...
#   Procesadas 7000 imágenes...
#   Procesadas 7050 imágenes...
#   Procesadas 7100 imágenes...
#   Procesadas 7150 imágenes...
#   Procesadas 7200 imágenes...
#   Procesadas 7250 imágenes...
#   Procesadas 7300 imágenes...
#   Procesadas 7350 imágenes...
#   Procesadas 7400 imágenes...
#   Procesadas 7450 imágenes...
#   Procesadas 7500 imágenes...
#   Procesadas 7550 imágenes...
#   Procesadas 7600 imágenes...
#   Procesadas 7650 imágenes...
#   Procesadas 7700 imágenes...
#   Procesadas 7750 imágenes...
#   Procesadas 7800 imágenes...
#   Procesadas 7850 imágenes...
#   Procesadas 7900 imágenes...
#   Procesadas 7950 imágenes...
#   Procesadas 8000 imágenes...
#   Procesadas 8050 imágenes...
#   Procesadas 8100 imágenes...
#   Procesadas 8150 imágenes...
#   Procesadas 8200 imágenes...
#   Procesadas 8250 imágenes...
#   Procesadas 8300 imágenes...
#   Procesadas 8350 imágenes...
#   Procesadas 8400 imágenes...
#   Procesadas 8450 imágenes...
#   Procesadas 8500 imágenes...
#   Procesadas 8550 imágenes...
#   Procesadas 8600 imágenes...
#   Procesadas 8650 imágenes...
#   Procesadas 8700 imágenes...
#   Procesadas 8750 imágenes...
#   Procesadas 8800 imágenes...
#   Procesadas 8850 imágenes...
#   Procesadas 8900 imágenes...
#   Procesadas 8950 imágenes...
#   Procesadas 9000 imágenes...
#   Procesadas 9050 imágenes...
#   Procesadas 9100 imágenes...
#   Procesadas 9150 imágenes...
#   Procesadas 9200 imágenes...
#   Procesadas 9250 imágenes...
#   Procesadas 9300 imágenes...
#   Procesadas 9350 imágenes...
#   Procesadas 9400 imágenes...
#   Procesadas 9450 imágenes...
#   Procesadas 9500 imágenes...
#   Procesadas 9550 imágenes...
#   Procesadas 9600 imágenes...
#   Procesadas 9650 imágenes...
#   Procesadas 9700 imágenes...
#   Procesadas 9750 imágenes...
#   Procesadas 9800 imágenes...
#   Procesadas 9850 imágenes...
#   Procesadas 9900 imágenes...
#   Procesadas 9950 imágenes...
#   Procesadas 10000 imágenes...
#   Procesadas 10050 imágenes...
#   Procesadas 10100 imágenes...
#   Procesadas 10150 imágenes...
#   Procesadas 10200 imágenes...
#   Procesadas 10250 imágenes...
#   Procesadas 10300 imágenes...
#   Procesadas 10350 imágenes...
#   Procesadas 10400 imágenes...
#   Procesadas 10450 imágenes...
#   Procesadas 10500 imágenes...
#   Procesadas 10550 imágenes...
#   Procesadas 10600 imágenes...
#   Procesadas 10650 imágenes...
#   Procesadas 10700 imágenes...
#   Procesadas 10750 imágenes...
#   Procesadas 10800 imágenes...
#   Procesadas 10850 imágenes...
#   Procesadas 10900 imágenes...
#   Procesadas 10950 imágenes...
#   Procesadas 11000 imágenes...
#   Procesadas 11050 imágenes...
#   Procesadas 11100 imágenes...
#   Procesadas 11150 imágenes...
#   Procesadas 11200 imágenes...
#   Procesadas 11250 imágenes...
#   Procesadas 11300 imágenes...
#   Procesadas 11350 imágenes...
#   Procesadas 11400 imágenes...
#   Procesadas 11450 imágenes...
#   Procesadas 11500 imágenes...
#   Procesadas 11550 imágenes...
#   Procesadas 11600 imágenes...
#   Procesadas 11650 imágenes...
#   Procesadas 11700 imágenes...
#   Procesadas 11750 imágenes...
#   Procesadas 11800 imágenes...
#   Procesadas 11850 imágenes...
#   Procesadas 11900 imágenes...
#   Procesadas 11950 imágenes...
#   Procesadas 12000 imágenes...
#   Procesadas 12050 imágenes...
#   Procesadas 12100 imágenes...
#   Procesadas 12150 imágenes...
#   Procesadas 12200 imágenes...
#   Procesadas 12250 imágenes...
#   Procesadas 12300 imágenes...
#   Procesadas 12350 imágenes...
#   Procesadas 12400 imágenes...
#   Procesadas 12450 imágenes...
#   Procesadas 12500 imágenes...
#   Procesadas 12550 imágenes...
#   Procesadas 12600 imágenes...
#   Procesadas 12650 imágenes...
#   Procesadas 12700 imágenes...
#   Procesadas 12750 imágenes...
#   Procesadas 12800 imágenes...
#   Procesadas 12850 imágenes...
#   Procesadas 12900 imágenes...
#   Procesadas 12950 imágenes...
#   Procesadas 13000 imágenes...
#   Procesadas 13050 imágenes...
#   Procesadas 13100 imágenes...
#   Procesadas 13150 imágenes...
#   Procesadas 13200 imágenes...
#   Procesadas 13250 imágenes...
#   Procesadas 13300 imágenes...
#   Procesadas 13350 imágenes...
#   Procesadas 13400 imágenes...
#   Procesadas 13450 imágenes...
#   Procesadas 13500 imágenes...
#   Procesadas 13550 imágenes...
#   Procesadas 13600 imágenes...
#   Procesadas 13650 imágenes...
#   Procesadas 13700 imágenes...
#   Procesadas 13750 imágenes...
#   Procesadas 13800 imágenes...
#   Procesadas 13850 imágenes...
#   Procesadas 13900 imágenes...
#   Procesadas 13950 imágenes...
#   Procesadas 14000 imágenes...
#   Procesadas 14050 imágenes...
#   Procesadas 14100 imágenes...
#   Procesadas 14150 imágenes...
#   Procesadas 14200 imágenes...
#   Procesadas 14250 imágenes...
#   Procesadas 14300 imágenes...
#   Procesadas 14350 imágenes...
#   Procesadas 14400 imágenes...
#   Procesadas 14450 imágenes...
#   Procesadas 14500 imágenes...
#   Procesadas 14550 imágenes...
#   Procesadas 14600 imágenes...
#   Procesadas 14650 imágenes...
#   Procesadas 14700 imágenes...
#   Procesadas 14750 imágenes...
#   Procesadas 14800 imágenes...
#   Procesadas 14850 imágenes...
#   Procesadas 14900 imágenes...
#   Procesadas 14950 imágenes...
#   Procesadas 15000 imágenes...
#   Procesadas 15050 imágenes...
#   Procesadas 15100 imágenes...
#   Procesadas 15150 imágenes...
#   Procesadas 15200 imágenes...
#   Procesadas 15250 imágenes...
#   Procesadas 15300 imágenes...
#   Procesadas 15350 imágenes...
#   Procesadas 15400 imágenes...
#   Procesadas 15450 imágenes...
#   Procesadas 15500 imágenes...
#   Procesadas 15550 imágenes...
#   Procesadas 15600 imágenes...
#   Procesadas 15650 imágenes...
#   Procesadas 15700 imágenes...
#   Procesadas 15750 imágenes...
#   Procesadas 15800 imágenes...
#   Procesadas 15850 imágenes...
#   Procesadas 15900 imágenes...
#   Procesadas 15950 imágenes...
#   Procesadas 16000 imágenes...
#   Procesadas 16050 imágenes...
#   Procesadas 16100 imágenes...
#   Procesadas 16150 imágenes...
#   Procesadas 16200 imágenes...
#   Procesadas 16250 imágenes...
#   Procesadas 16300 imágenes...
#   Procesadas 16350 imágenes...
#   Procesadas 16400 imágenes...
#   Procesadas 16450 imágenes...
#   Procesadas 16500 imágenes...
#   Procesadas 16550 imágenes...
#   Procesadas 16600 imágenes...
#   Procesadas 16650 imágenes...
#   Procesadas 16700 imágenes...
#   Procesadas 16750 imágenes...
#   Procesadas 16800 imágenes...
#   Procesadas 16850 imágenes...
#   Procesadas 16900 imágenes...
#   Procesadas 16950 imágenes...
#   Procesadas 17000 imágenes...
#   Procesadas 17050 imágenes...
#   Procesadas 17100 imágenes...
#   Procesadas 17150 imágenes...
#   Procesadas 17200 imágenes...
#   Procesadas 17250 imágenes...
#   Procesadas 17300 imágenes...
#   Procesadas 17350 imágenes...
#   Procesadas 17400 imágenes...
#   Procesadas 17450 imágenes...
#   Procesadas 17500 imágenes...
#   Procesadas 17550 imágenes...
#   Procesadas 17600 imágenes...
#   Procesadas 17650 imágenes...
#   Procesadas 17700 imágenes...
#   Procesadas 17750 imágenes...
#   Procesadas 17800 imágenes...
#   Procesadas 17850 imágenes...
#   Procesadas 17900 imágenes...
#   Procesadas 17950 imágenes...
#   Procesadas 18000 imágenes...
#   Procesadas 18050 imágenes...
#   Procesadas 18100 imágenes...
#   Procesadas 18150 imágenes...
#   Procesadas 18200 imágenes...
#   Procesadas 18250 imágenes...
#   Procesadas 18300 imágenes...
#   Procesadas 18350 imágenes...
#   Procesadas 18400 imágenes...
#   Procesadas 18450 imágenes...
#   Procesadas 18500 imágenes...
#   Procesadas 18550 imágenes...
#   Procesadas 18600 imágenes...
#   Procesadas 18650 imágenes...
#   Procesadas 18700 imágenes...
#   Procesadas 18750 imágenes...
#   Procesadas 18800 imágenes...
#   Procesadas 18850 imágenes...
#   Procesadas 18900 imágenes...
#   Procesadas 18950 imágenes...
#   Procesadas 19000 imágenes...
#   Procesadas 19050 imágenes...
#   Procesadas 19100 imágenes...
#   Procesadas 19150 imágenes...
#   Procesadas 19200 imágenes...
#   Procesadas 19250 imágenes...
#   Procesadas 19300 imágenes...
#   Procesadas 19350 imágenes...
#   Procesadas 19400 imágenes...
#   Procesadas 19450 imágenes...
#   Procesadas 19500 imágenes...
#   Procesadas 19550 imágenes...
#   Procesadas 19600 imágenes...
#   Procesadas 19650 imágenes...
#   Procesadas 19700 imágenes...
#   Procesadas 19750 imágenes...
#   Procesadas 19800 imágenes...
#   Procesadas 19850 imágenes...
#   Procesadas 19900 imágenes...
#   Procesadas 19950 imágenes...
#   Procesadas 20000 imágenes...
#   Procesadas 20050 imágenes...
#   Procesadas 20100 imágenes...
#   Procesadas 20150 imágenes...
#   Procesadas 20200 imágenes...
#   Procesadas 20250 imágenes...
#   Procesadas 20300 imágenes...
#   Procesadas 20350 imágenes...
#   Procesadas 20400 imágenes...
#   Procesadas 20450 imágenes...
#   Procesadas 20500 imágenes...
#   Procesadas 20550 imágenes...
#   Procesadas 20600 imágenes...
#   Procesadas 20650 imágenes...
#   Procesadas 20700 imágenes...
#   Procesadas 20750 imágenes...
#   Procesadas 20800 imágenes...
#   Procesadas 20850 imágenes...
#   Procesadas 20900 imágenes...
#   Procesadas 20950 imágenes...
#   Procesadas 21000 imágenes...
#   Procesadas 21050 imágenes...
#   Procesadas 21100 imágenes...
#   Procesadas 21150 imágenes...
#   Procesadas 21200 imágenes...
#   Procesadas 21250 imágenes...
#   Procesadas 21300 imágenes...
#   Procesadas 21350 imágenes...
#   Procesadas 21400 imágenes...
#   Procesadas 21450 imágenes...
#   Procesadas 21500 imágenes...
#   Procesadas 21550 imágenes...
#   Procesadas 21600 imágenes...
#   Procesadas 21650 imágenes...
#   Procesadas 21700 imágenes...
#   Procesadas 21750 imágenes...
#   Procesadas 21800 imágenes...
#   Procesadas 21850 imágenes...
#   Procesadas 21900 imágenes...
#   ✓ Completado: 21912 imágenes procesadas
#
# Procesando carpeta: Hormiga
#   Procesadas 50 imágenes...
#   Procesadas 100 imágenes...
#   Procesadas 150 imágenes...
#   Procesadas 200 imágenes...
#   Procesadas 250 imágenes...
#   Procesadas 300 imágenes...
#   Procesadas 350 imágenes...
#   Procesadas 400 imágenes...
#   Procesadas 450 imágenes...
#   Procesadas 500 imágenes...
#   Procesadas 550 imágenes...
#   Procesadas 600 imágenes...
#   Procesadas 650 imágenes...
#   Procesadas 700 imágenes...
#   Procesadas 750 imágenes...
#   Procesadas 800 imágenes...
#   Procesadas 850 imágenes...
#   Procesadas 900 imágenes...
#   Procesadas 950 imágenes...
#   Procesadas 1000 imágenes...
#   Procesadas 1050 imágenes...
#   Procesadas 1100 imágenes...
#   Procesadas 1150 imágenes...
#   Procesadas 1200 imágenes...
#   Procesadas 1250 imágenes...
#   Procesadas 1300 imágenes...
#   Procesadas 1350 imágenes...
#   Procesadas 1400 imágenes...
#   Procesadas 1450 imágenes...
#   Procesadas 1500 imágenes...
#   Procesadas 1550 imágenes...
#   Procesadas 1600 imágenes...
#   Procesadas 1650 imágenes...
#   Procesadas 1700 imágenes...
#   Procesadas 1750 imágenes...
#   Procesadas 1800 imágenes...
#   Procesadas 1850 imágenes...
#   Procesadas 1900 imágenes...
#   Procesadas 1950 imágenes...
#   Procesadas 2000 imágenes...
#   Procesadas 2050 imágenes...
#   Procesadas 2100 imágenes...
#   Procesadas 2150 imágenes...
#   Procesadas 2200 imágenes...
#   Procesadas 2250 imágenes...
#   Procesadas 2300 imágenes...
#   Procesadas 2350 imágenes...
#   Procesadas 2400 imágenes...
#   Procesadas 2450 imágenes...
#   Procesadas 2500 imágenes...
#   Procesadas 2550 imágenes...
#   Procesadas 2600 imágenes...
#   Procesadas 2650 imágenes...
#   Procesadas 2700 imágenes...
#   Procesadas 2750 imágenes...
#   Procesadas 2800 imágenes...
#   Procesadas 2850 imágenes...
#   Procesadas 2900 imágenes...
#   Procesadas 2950 imágenes...
#   Procesadas 3000 imágenes...
#   Procesadas 3050 imágenes...
#   Procesadas 3100 imágenes...
#   Procesadas 3150 imágenes...
#   Procesadas 3200 imágenes...
#   Procesadas 3250 imágenes...
#   Procesadas 3300 imágenes...
#   Procesadas 3350 imágenes...
#   Procesadas 3400 imágenes...
#   Procesadas 3450 imágenes...
#   Procesadas 3500 imágenes...
#   Procesadas 3550 imágenes...
#   Procesadas 3600 imágenes...
#   Procesadas 3650 imágenes...
#   Procesadas 3700 imágenes...
#   Procesadas 3750 imágenes...
#   Procesadas 3800 imágenes...
#   Procesadas 3850 imágenes...
#   Procesadas 3900 imágenes...
#   Procesadas 3950 imágenes...
#   Procesadas 4000 imágenes...
#   Procesadas 4050 imágenes...
#   Procesadas 4100 imágenes...
#   Procesadas 4150 imágenes...
#   Procesadas 4200 imágenes...
#   Procesadas 4250 imágenes...
#   Procesadas 4300 imágenes...
#   Procesadas 4350 imágenes...
#   Procesadas 4400 imágenes...
#   Procesadas 4450 imágenes...
#   Procesadas 4500 imágenes...
#   Procesadas 4550 imágenes...
#   Procesadas 4600 imágenes...
#   Procesadas 4650 imágenes...
#   Procesadas 4700 imágenes...
#   Procesadas 4750 imágenes...
#   Procesadas 4800 imágenes...
#   Procesadas 4850 imágenes...
#   Procesadas 4900 imágenes...
#   Procesadas 4950 imágenes...
#   Procesadas 5000 imágenes...
#   Procesadas 5050 imágenes...
#   Procesadas 5100 imágenes...
#   Procesadas 5150 imágenes...
#   Procesadas 5200 imágenes...
#   Procesadas 5250 imágenes...
#   Procesadas 5300 imágenes...
#   Procesadas 5350 imágenes...
#   Procesadas 5400 imágenes...
#   Procesadas 5450 imágenes...
#   Procesadas 5500 imágenes...
#   Procesadas 5550 imágenes...
#   Procesadas 5600 imágenes...
#   Procesadas 5650 imágenes...
#   Procesadas 5700 imágenes...
#   Procesadas 5750 imágenes...
#   Procesadas 5800 imágenes...
#   Procesadas 5850 imágenes...
#   Procesadas 5900 imágenes...
#   Procesadas 5950 imágenes...
#   Procesadas 6000 imágenes...
#   Procesadas 6050 imágenes...
#   Procesadas 6100 imágenes...
#   Procesadas 6150 imágenes...
#   Procesadas 6200 imágenes...
#   Procesadas 6250 imágenes...
#   Procesadas 6300 imágenes...
#   Procesadas 6350 imágenes...
#   Procesadas 6400 imágenes...
#   Procesadas 6450 imágenes...
#   Procesadas 6500 imágenes...
#   Procesadas 6550 imágenes...
#   Procesadas 6600 imágenes...
#   Procesadas 6650 imágenes...
#   Procesadas 6700 imágenes...
#   Procesadas 6750 imágenes...
#   Procesadas 6800 imágenes...
#   Procesadas 6850 imágenes...
#   Procesadas 6900 imágenes...
#   Procesadas 6950 imágenes...
#   Procesadas 7000 imágenes...
#   Procesadas 7050 imágenes...
#   Procesadas 7100 imágenes...
#   Procesadas 7150 imágenes...
#   Procesadas 7200 imágenes...
#   Procesadas 7250 imágenes...
#   Procesadas 7300 imágenes...
#   Procesadas 7350 imágenes...
#   Procesadas 7400 imágenes...
#   Procesadas 7450 imágenes...
#   Procesadas 7500 imágenes...
#   Procesadas 7550 imágenes...
#   Procesadas 7600 imágenes...
#   Procesadas 7650 imágenes...
#   Procesadas 7700 imágenes...
#   Procesadas 7750 imágenes...
#   Procesadas 7800 imágenes...
#   Procesadas 7850 imágenes...
#   Procesadas 7900 imágenes...
#   Procesadas 7950 imágenes...
#   Procesadas 8000 imágenes...
#   Procesadas 8050 imágenes...
#   Procesadas 8100 imágenes...
#   Procesadas 8150 imágenes...
#   Procesadas 8200 imágenes...
#   Procesadas 8250 imágenes...
#   Procesadas 8300 imágenes...
#   Procesadas 8350 imágenes...
#   Procesadas 8400 imágenes...
#   Procesadas 8450 imágenes...
#   Procesadas 8500 imágenes...
#   Procesadas 8550 imágenes...
#   Procesadas 8600 imágenes...
#   Procesadas 8650 imágenes...
#   Procesadas 8700 imágenes...
#   Procesadas 8750 imágenes...
#   Procesadas 8800 imágenes...
#   Procesadas 8850 imágenes...
#   Procesadas 8900 imágenes...
#   Procesadas 8950 imágenes...
#   Procesadas 9000 imágenes...
#   Procesadas 9050 imágenes...
#   Procesadas 9100 imágenes...
#   Procesadas 9150 imágenes...
#   Procesadas 9200 imágenes...
#   Procesadas 9250 imágenes...
#   Procesadas 9300 imágenes...
#   Procesadas 9350 imágenes...
#   Procesadas 9400 imágenes...
#   Procesadas 9450 imágenes...
#   Procesadas 9500 imágenes...
#   Procesadas 9550 imágenes...
#   Procesadas 9600 imágenes...
#   Procesadas 9650 imágenes...
#   Procesadas 9700 imágenes...
#   Procesadas 9750 imágenes...
#   Procesadas 9800 imágenes...
#   Procesadas 9850 imágenes...
#   Procesadas 9900 imágenes...
#   Procesadas 9950 imágenes...
#   Procesadas 10000 imágenes...
#   Procesadas 10050 imágenes...
#   Procesadas 10100 imágenes...
#   Procesadas 10150 imágenes...
#   Procesadas 10200 imágenes...
#   Procesadas 10250 imágenes...
#   Procesadas 10300 imágenes...
#   Procesadas 10350 imágenes...
#   Procesadas 10400 imágenes...
#   Procesadas 10450 imágenes...
#   Procesadas 10500 imágenes...
#   Procesadas 10550 imágenes...
#   Procesadas 10600 imágenes...
#   Procesadas 10650 imágenes...
#   Procesadas 10700 imágenes...
#   Procesadas 10750 imágenes...
#   Procesadas 10800 imágenes...
#   Procesadas 10850 imágenes...
#   Procesadas 10900 imágenes...
#   Procesadas 10950 imágenes...
#   Procesadas 11000 imágenes...
#   Procesadas 11050 imágenes...
#   Procesadas 11100 imágenes...
#   Procesadas 11150 imágenes...
#   Procesadas 11200 imágenes...
#   Procesadas 11250 imágenes...
#   Procesadas 11300 imágenes...
#   Procesadas 11350 imágenes...
#   Procesadas 11400 imágenes...
#   Procesadas 11450 imágenes...
#   Procesadas 11500 imágenes...
#   Procesadas 11550 imágenes...
#   Procesadas 11600 imágenes...
#   Procesadas 11650 imágenes...
#   Procesadas 11700 imágenes...
#   Procesadas 11750 imágenes...
#   Procesadas 11800 imágenes...
#   Procesadas 11850 imágenes...
#   Procesadas 11900 imágenes...
#   Procesadas 11950 imágenes...
#   Procesadas 12000 imágenes...
#   Procesadas 12050 imágenes...
#   Procesadas 12100 imágenes...
#   Procesadas 12150 imágenes...
#   Procesadas 12200 imágenes...
#   Procesadas 12250 imágenes...
#   Procesadas 12300 imágenes...
#   Procesadas 12350 imágenes...
#   Procesadas 12400 imágenes...
#   Procesadas 12450 imágenes...
#   Procesadas 12500 imágenes...
#   Procesadas 12550 imágenes...
#   Procesadas 12600 imágenes...
#   Procesadas 12650 imágenes...
#   Procesadas 12700 imágenes...
#   Procesadas 12750 imágenes...
#   Procesadas 12800 imágenes...
#   Procesadas 12850 imágenes...
#   Procesadas 12900 imágenes...
#   Procesadas 12950 imágenes...
#   Procesadas 13000 imágenes...
#   Procesadas 13050 imágenes...
#   Procesadas 13100 imágenes...
#   Procesadas 13150 imágenes...
#   Procesadas 13200 imágenes...
#   Procesadas 13250 imágenes...
#   Procesadas 13300 imágenes...
#   Procesadas 13350 imágenes...
#   Procesadas 13400 imágenes...
#   Procesadas 13450 imágenes...
#   Procesadas 13500 imágenes...
#   Procesadas 13550 imágenes...
#   Procesadas 13600 imágenes...
#   Procesadas 13650 imágenes...
#   Procesadas 13700 imágenes...
#   Procesadas 13750 imágenes...
#   Procesadas 13800 imágenes...
#   Procesadas 13850 imágenes...
#   Procesadas 13900 imágenes...
#   Procesadas 13950 imágenes...
#   Procesadas 14000 imágenes...
#   Procesadas 14050 imágenes...
#   Procesadas 14100 imágenes...
#   Procesadas 14150 imágenes...
#   Procesadas 14200 imágenes...
#   Procesadas 14250 imágenes...
#   Procesadas 14300 imágenes...
#   Procesadas 14350 imágenes...
#   Procesadas 14400 imágenes...
#   Procesadas 14450 imágenes...
#   Procesadas 14500 imágenes...
#   Procesadas 14550 imágenes...
#   Procesadas 14600 imágenes...
#   Procesadas 14650 imágenes...
#   Procesadas 14700 imágenes...
#   Procesadas 14750 imágenes...
#   Procesadas 14800 imágenes...
#   Procesadas 14850 imágenes...
#   Procesadas 14900 imágenes...
#   Procesadas 14950 imágenes...
#   Procesadas 15000 imágenes...
#   Procesadas 15050 imágenes...
#   Procesadas 15100 imágenes...
#   Procesadas 15150 imágenes...
#   Procesadas 15200 imágenes...
#   Procesadas 15250 imágenes...
#   Procesadas 15300 imágenes...
#   Procesadas 15350 imágenes...
#   Procesadas 15400 imágenes...
#   Procesadas 15450 imágenes...
#   Procesadas 15500 imágenes...
#   Procesadas 15550 imágenes...
#   Procesadas 15600 imágenes...
#   Procesadas 15650 imágenes...
#   Procesadas 15700 imágenes...
#   Procesadas 15750 imágenes...
#   Procesadas 15800 imágenes...
#   Procesadas 15850 imágenes...
#   Procesadas 15900 imágenes...
#   Procesadas 15950 imágenes...
#   Procesadas 16000 imágenes...
#   Procesadas 16050 imágenes...
#   Procesadas 16100 imágenes...
#   Procesadas 16150 imágenes...
#   Procesadas 16200 imágenes...
#   Procesadas 16250 imágenes...
#   Procesadas 16300 imágenes...
#   Procesadas 16350 imágenes...
#   Procesadas 16400 imágenes...
#   Procesadas 16450 imágenes...
#   Procesadas 16500 imágenes...
#   Procesadas 16550 imágenes...
#   Procesadas 16600 imágenes...
#   Procesadas 16650 imágenes...
#   Procesadas 16700 imágenes...
#   Procesadas 16750 imágenes...
#   Procesadas 16800 imágenes...
#   Procesadas 16850 imágenes...
#   Procesadas 16900 imágenes...
#   Procesadas 16950 imágenes...
#   Procesadas 17000 imágenes...
#   Procesadas 17050 imágenes...
#   Procesadas 17100 imágenes...
#   Procesadas 17150 imágenes...
#   Procesadas 17200 imágenes...
#   Procesadas 17250 imágenes...
#   Procesadas 17300 imágenes...
#   Procesadas 17350 imágenes...
#   Procesadas 17400 imágenes...
#   Procesadas 17450 imágenes...
#   Procesadas 17500 imágenes...
#   Procesadas 17550 imágenes...
#   Procesadas 17600 imágenes...
#   Procesadas 17650 imágenes...
#   Procesadas 17700 imágenes...
#   Procesadas 17750 imágenes...
#   Procesadas 17800 imágenes...
#   Procesadas 17850 imágenes...
#   Procesadas 17900 imágenes...
#   Procesadas 17950 imágenes...
#   Procesadas 18000 imágenes...
#   Procesadas 18050 imágenes...
#   Procesadas 18100 imágenes...
#   Procesadas 18150 imágenes...
#   Procesadas 18200 imágenes...
#   Procesadas 18250 imágenes...
#   Procesadas 18300 imágenes...
#   Procesadas 18350 imágenes...
#   Procesadas 18400 imágenes...
#   Procesadas 18450 imágenes...
#   Procesadas 18500 imágenes...
#   Procesadas 18550 imágenes...
#   Procesadas 18600 imágenes...
#   Procesadas 18650 imágenes...
#   Procesadas 18700 imágenes...
#   Procesadas 18750 imágenes...
#   Procesadas 18800 imágenes...
#   Procesadas 18850 imágenes...
#   Procesadas 18900 imágenes...
#   Procesadas 18950 imágenes...
#   Procesadas 19000 imágenes...
#   Procesadas 19050 imágenes...
#   Procesadas 19100 imágenes...
#   Procesadas 19150 imágenes...
#   Procesadas 19200 imágenes...
#   Procesadas 19250 imágenes...
#   Procesadas 19300 imágenes...
#   Procesadas 19350 imágenes...
#   Procesadas 19400 imágenes...
#   Procesadas 19450 imágenes...
#   Procesadas 19500 imágenes...
#   Procesadas 19550 imágenes...
#   Procesadas 19600 imágenes...
#   Procesadas 19650 imágenes...
#   Procesadas 19700 imágenes...
#   Procesadas 19750 imágenes...
#   Procesadas 19800 imágenes...
#   Procesadas 19850 imágenes...
#   Procesadas 19900 imágenes...
#   Procesadas 19950 imágenes...
#   Procesadas 20000 imágenes...
#   Procesadas 20050 imágenes...
#   Procesadas 20100 imágenes...
#   Procesadas 20150 imágenes...
#   Procesadas 20200 imágenes...
#   Procesadas 20250 imágenes...
#   Procesadas 20300 imágenes...
#   Procesadas 20350 imágenes...
#   Procesadas 20400 imágenes...
#   Procesadas 20450 imágenes...
#   Procesadas 20500 imágenes...
#   Procesadas 20550 imágenes...
#   Procesadas 20600 imágenes...
#   Procesadas 20650 imágenes...
#   Procesadas 20700 imágenes...
#   Procesadas 20750 imágenes...
#   Procesadas 20800 imágenes...
#   Procesadas 20850 imágenes...
#   Procesadas 20900 imágenes...
#   Procesadas 20950 imágenes...
#   Procesadas 21000 imágenes...
#   Procesadas 21050 imágenes...
#   Procesadas 21100 imágenes...
#   Procesadas 21150 imágenes...
#   Procesadas 21200 imágenes...
#   Procesadas 21250 imágenes...
#   Procesadas 21300 imágenes...
#   Procesadas 21350 imágenes...
#   Procesadas 21400 imágenes...
#   Procesadas 21450 imágenes...
#   Procesadas 21500 imágenes...
#   Procesadas 21550 imágenes...
#   Procesadas 21600 imágenes...
#   Procesadas 21650 imágenes...
#   Procesadas 21700 imágenes...
#   Procesadas 21750 imágenes...
#   Procesadas 21800 imágenes...
#   Procesadas 21850 imágenes...
#   Procesadas 21900 imágenes...
#   Procesadas 21950 imágenes...
#   Procesadas 22000 imágenes...
#   Procesadas 22050 imágenes...
#   Procesadas 22100 imágenes...
#   Procesadas 22150 imágenes...
#   Procesadas 22200 imágenes...
#   Procesadas 22250 imágenes...
#   Procesadas 22300 imágenes...
#   Procesadas 22350 imágenes...
#   Procesadas 22400 imágenes...
#   Procesadas 22450 imágenes...
#   Procesadas 22500 imágenes...
#   Procesadas 22550 imágenes...
#   Procesadas 22600 imágenes...
#   ✓ Completado: 22618 imágenes procesadas
#
# Procesando carpeta: Mariquita
#   Procesadas 50 imágenes...
#   Procesadas 100 imágenes...
#   Procesadas 150 imágenes...
#   Procesadas 200 imágenes...
#   Procesadas 250 imágenes...
#   Procesadas 300 imágenes...
#   Procesadas 350 imágenes...
#   Procesadas 400 imágenes...
#   Procesadas 450 imágenes...
#   Procesadas 500 imágenes...
#   Procesadas 550 imágenes...
#   Procesadas 600 imágenes...
#   Procesadas 650 imágenes...
#   Procesadas 700 imágenes...
#   Procesadas 750 imágenes...
#   Procesadas 800 imágenes...
#   Procesadas 850 imágenes...
#   Procesadas 900 imágenes...
#   Procesadas 950 imágenes...
#   Procesadas 1000 imágenes...
#   Procesadas 1050 imágenes...
#   Procesadas 1100 imágenes...
#   Procesadas 1150 imágenes...
#   Procesadas 1200 imágenes...
#   Procesadas 1250 imágenes...
#   Procesadas 1300 imágenes...
#   Procesadas 1350 imágenes...
#   Procesadas 1400 imágenes...
#   Procesadas 1450 imágenes...
#   Procesadas 1500 imágenes...
#   Procesadas 1550 imágenes...
#   Procesadas 1600 imágenes...
#   Procesadas 1650 imágenes...
#   Procesadas 1700 imágenes...
#   Procesadas 1750 imágenes...
#   Procesadas 1800 imágenes...
#   Procesadas 1850 imágenes...
#   Procesadas 1900 imágenes...
#   Procesadas 1950 imágenes...
#   Procesadas 2000 imágenes...
#   Procesadas 2050 imágenes...
#   Procesadas 2100 imágenes...
#   Procesadas 2150 imágenes...
#   Procesadas 2200 imágenes...
#   Procesadas 2250 imágenes...
#   Procesadas 2300 imágenes...
#   Procesadas 2350 imágenes...
#   Procesadas 2400 imágenes...
#   Procesadas 2450 imágenes...
#   Procesadas 2500 imágenes...
#   Procesadas 2550 imágenes...
#   Procesadas 2600 imágenes...
#   Procesadas 2650 imágenes...
#   Procesadas 2700 imágenes...
#   Procesadas 2750 imágenes...
#   Procesadas 2800 imágenes...
#   Procesadas 2850 imágenes...
#   Procesadas 2900 imágenes...
#   Procesadas 2950 imágenes...
#   Procesadas 3000 imágenes...
#   Procesadas 3050 imágenes...
#   Procesadas 3100 imágenes...
#   Procesadas 3150 imágenes...
#   Procesadas 3200 imágenes...
#   Procesadas 3250 imágenes...
#   Procesadas 3300 imágenes...
#   Procesadas 3350 imágenes...
#   Procesadas 3400 imágenes...
#   Procesadas 3450 imágenes...
#   Procesadas 3500 imágenes...
#   Procesadas 3550 imágenes...
#   Procesadas 3600 imágenes...
#   Procesadas 3650 imágenes...
#   Procesadas 3700 imágenes...
#   Procesadas 3750 imágenes...
#   Procesadas 3800 imágenes...
#   Procesadas 3850 imágenes...
#   Procesadas 3900 imágenes...
#   Procesadas 3950 imágenes...
#   Procesadas 4000 imágenes...
#   Procesadas 4050 imágenes...
#   Procesadas 4100 imágenes...
#   Procesadas 4150 imágenes...
#   Procesadas 4200 imágenes...
#   Procesadas 4250 imágenes...
#   Procesadas 4300 imágenes...
#   Procesadas 4350 imágenes...
#   Procesadas 4400 imágenes...
#   Procesadas 4450 imágenes...
#   Procesadas 4500 imágenes...
#   Procesadas 4550 imágenes...
#   Procesadas 4600 imágenes...
#   Procesadas 4650 imágenes...
#   Procesadas 4700 imágenes...
#   Procesadas 4750 imágenes...
#   Procesadas 4800 imágenes...
#   Procesadas 4850 imágenes...
#   Procesadas 4900 imágenes...
#   Procesadas 4950 imágenes...
#   Procesadas 5000 imágenes...
#   Procesadas 5050 imágenes...
#   Procesadas 5100 imágenes...
#   Procesadas 5150 imágenes...
#   Procesadas 5200 imágenes...
#   Procesadas 5250 imágenes...
#   Procesadas 5300 imágenes...
#   Procesadas 5350 imágenes...
#   Procesadas 5400 imágenes...
#   Procesadas 5450 imágenes...
#   Procesadas 5500 imágenes...
#   Procesadas 5550 imágenes...
#   Procesadas 5600 imágenes...
#   Procesadas 5650 imágenes...
#   Procesadas 5700 imágenes...
#   Procesadas 5750 imágenes...
#   Procesadas 5800 imágenes...
#   Procesadas 5850 imágenes...
#   Procesadas 5900 imágenes...
#   Procesadas 5950 imágenes...
#   Procesadas 6000 imágenes...
#   Procesadas 6050 imágenes...
#   Procesadas 6100 imágenes...
#   Procesadas 6150 imágenes...
#   Procesadas 6200 imágenes...
#   Procesadas 6250 imágenes...
#   Procesadas 6300 imágenes...
#   Procesadas 6350 imágenes...
#   Procesadas 6400 imágenes...
#   Procesadas 6450 imágenes...
#   Procesadas 6500 imágenes...
#   Procesadas 6550 imágenes...
#   Procesadas 6600 imágenes...
#   Procesadas 6650 imágenes...
#   Procesadas 6700 imágenes...
#   Procesadas 6750 imágenes...
#   Procesadas 6800 imágenes...
#   Procesadas 6850 imágenes...
#   Procesadas 6900 imágenes...
#   Procesadas 6950 imágenes...
#   Procesadas 7000 imágenes...
#   Procesadas 7050 imágenes...
#   Procesadas 7100 imágenes...
#   Procesadas 7150 imágenes...
#   Procesadas 7200 imágenes...
#   Procesadas 7250 imágenes...
#   Procesadas 7300 imágenes...
#   Procesadas 7350 imágenes...
#   Procesadas 7400 imágenes...
#   Procesadas 7450 imágenes...
#   Procesadas 7500 imágenes...
#   Procesadas 7550 imágenes...
#   Procesadas 7600 imágenes...
#   Procesadas 7650 imágenes...
#   Procesadas 7700 imágenes...
#   Procesadas 7750 imágenes...
#   Procesadas 7800 imágenes...
#   Procesadas 7850 imágenes...
#   Procesadas 7900 imágenes...
#   Procesadas 7950 imágenes...
#   Procesadas 8000 imágenes...
#   Procesadas 8050 imágenes...
#   Procesadas 8100 imágenes...
#   Procesadas 8150 imágenes...
#   Procesadas 8200 imágenes...
#   Procesadas 8250 imágenes...
#   Procesadas 8300 imágenes...
#   Procesadas 8350 imágenes...
#   Procesadas 8400 imágenes...
#   Procesadas 8450 imágenes...
#   Procesadas 8500 imágenes...
#   Procesadas 8550 imágenes...
#   Procesadas 8600 imágenes...
#   Procesadas 8650 imágenes...
#   Procesadas 8700 imágenes...
#   Procesadas 8750 imágenes...
#   Procesadas 8800 imágenes...
#   Procesadas 8850 imágenes...
#   Procesadas 8900 imágenes...
#   Procesadas 8950 imágenes...
#   Procesadas 9000 imágenes...
#   Procesadas 9050 imágenes...
#   Procesadas 9100 imágenes...
#   Procesadas 9150 imágenes...
#   Procesadas 9200 imágenes...
#   Procesadas 9250 imágenes...
#   Procesadas 9300 imágenes...
#   Procesadas 9350 imágenes...
#   Procesadas 9400 imágenes...
#   Procesadas 9450 imágenes...
#   Procesadas 9500 imágenes...
#   Procesadas 9550 imágenes...
#   Procesadas 9600 imágenes...
#   Procesadas 9650 imágenes...
#   Procesadas 9700 imágenes...
#   Procesadas 9750 imágenes...
#   Procesadas 9800 imágenes...
#   Procesadas 9850 imágenes...
#   Procesadas 9900 imágenes...
#   Procesadas 9950 imágenes...
#   Procesadas 10000 imágenes...
#   Procesadas 10050 imágenes...
#   Procesadas 10100 imágenes...
#   Procesadas 10150 imágenes...
#   Procesadas 10200 imágenes...
#   Procesadas 10250 imágenes...
#   Procesadas 10300 imágenes...
#   Procesadas 10350 imágenes...
#   Procesadas 10400 imágenes...
#   Procesadas 10450 imágenes...
#   Procesadas 10500 imágenes...
#   Procesadas 10550 imágenes...
#   Procesadas 10600 imágenes...
#   Procesadas 10650 imágenes...
#   Procesadas 10700 imágenes...
#   Procesadas 10750 imágenes...
#   Procesadas 10800 imágenes...
#   Procesadas 10850 imágenes...
#   Procesadas 10900 imágenes...
#   Procesadas 10950 imágenes...
#   Procesadas 11000 imágenes...
#   Procesadas 11050 imágenes...
#   Procesadas 11100 imágenes...
#   Procesadas 11150 imágenes...
#   Procesadas 11200 imágenes...
#   Procesadas 11250 imágenes...
#   Procesadas 11300 imágenes...
#   Procesadas 11350 imágenes...
#   Procesadas 11400 imágenes...
#   Procesadas 11450 imágenes...
#   Procesadas 11500 imágenes...
#   Procesadas 11550 imágenes...
#   Procesadas 11600 imágenes...
#   Procesadas 11650 imágenes...
#   Procesadas 11700 imágenes...
#   Procesadas 11750 imágenes...
#   Procesadas 11800 imágenes...
#   Procesadas 11850 imágenes...
#   Procesadas 11900 imágenes...
#   Procesadas 11950 imágenes...
#   Procesadas 12000 imágenes...
#   Procesadas 12050 imágenes...
#   Procesadas 12100 imágenes...
#   Procesadas 12150 imágenes...
#   Procesadas 12200 imágenes...
#   Procesadas 12250 imágenes...
#   Procesadas 12300 imágenes...
#   Procesadas 12350 imágenes...
#   Procesadas 12400 imágenes...
#   Procesadas 12450 imágenes...
#   Procesadas 12500 imágenes...
#   Procesadas 12550 imágenes...
#   Procesadas 12600 imágenes...
#   Procesadas 12650 imágenes...
#   Procesadas 12700 imágenes...
#   Procesadas 12750 imágenes...
#   Procesadas 12800 imágenes...
#   Procesadas 12850 imágenes...
#   Procesadas 12900 imágenes...
#   Procesadas 12950 imágenes...
#   Procesadas 13000 imágenes...
#   Procesadas 13050 imágenes...
#   Procesadas 13100 imágenes...
#   Procesadas 13150 imágenes...
#   Procesadas 13200 imágenes...
#   Procesadas 13250 imágenes...
#   Procesadas 13300 imágenes...
#   Procesadas 13350 imágenes...
#   Procesadas 13400 imágenes...
#   Procesadas 13450 imágenes...
#   Procesadas 13500 imágenes...
#   Procesadas 13550 imágenes...
#   Procesadas 13600 imágenes...
#   Procesadas 13650 imágenes...
#   Procesadas 13700 imágenes...
#   Procesadas 13750 imágenes...
#   Procesadas 13800 imágenes...
#   Procesadas 13850 imágenes...
#   Procesadas 13900 imágenes...
#   Procesadas 13950 imágenes...
#   Procesadas 14000 imágenes...
#   Procesadas 14050 imágenes...
#   Procesadas 14100 imágenes...
#   Procesadas 14150 imágenes...
#   Procesadas 14200 imágenes...
#   Procesadas 14250 imágenes...
#   Procesadas 14300 imágenes...
#   Procesadas 14350 imágenes...
#   Procesadas 14400 imágenes...
#   Procesadas 14450 imágenes...
#   Procesadas 14500 imágenes...
#   Procesadas 14550 imágenes...
#   Procesadas 14600 imágenes...
#   Procesadas 14650 imágenes...
#   Procesadas 14700 imágenes...
#   Procesadas 14750 imágenes...
#   Procesadas 14800 imágenes...
#   Procesadas 14850 imágenes...
#   Procesadas 14900 imágenes...
#   Procesadas 14950 imágenes...
#   Procesadas 15000 imágenes...
#   Procesadas 15050 imágenes...
#   Procesadas 15100 imágenes...
#   Procesadas 15150 imágenes...
#   Procesadas 15200 imágenes...
#   Procesadas 15250 imágenes...
#   Procesadas 15300 imágenes...
#   Procesadas 15350 imágenes...
#   Procesadas 15400 imágenes...
#   Procesadas 15450 imágenes...
#   Procesadas 15500 imágenes...
#   Procesadas 15550 imágenes...
#   Procesadas 15600 imágenes...
#   Procesadas 15650 imágenes...
#   Procesadas 15700 imágenes...
#   Procesadas 15750 imágenes...
#   Procesadas 15800 imágenes...
#   Procesadas 15850 imágenes...
#   Procesadas 15900 imágenes...
#   Procesadas 15950 imágenes...
#   Procesadas 16000 imágenes...
#   Procesadas 16050 imágenes...
#   Procesadas 16100 imágenes...
#   Procesadas 16150 imágenes...
#   Procesadas 16200 imágenes...
#   Procesadas 16250 imágenes...
#   Procesadas 16300 imágenes...
#   Procesadas 16350 imágenes...
#   Procesadas 16400 imágenes...
#   Procesadas 16450 imágenes...
#   Procesadas 16500 imágenes...
#   Procesadas 16550 imágenes...
#   Procesadas 16600 imágenes...
#   Procesadas 16650 imágenes...
#   Procesadas 16700 imágenes...
#   Procesadas 16750 imágenes...
#   Procesadas 16800 imágenes...
#   Procesadas 16850 imágenes...
#   Procesadas 16900 imágenes...
#   Procesadas 16950 imágenes...
#   Procesadas 17000 imágenes...
#   Procesadas 17050 imágenes...
#   Procesadas 17100 imágenes...
#   Procesadas 17150 imágenes...
#   Procesadas 17200 imágenes...
#   Procesadas 17250 imágenes...
#   Procesadas 17300 imágenes...
#   Procesadas 17350 imágenes...
#   Procesadas 17400 imágenes...
#   Procesadas 17450 imágenes...
#   Procesadas 17500 imágenes...
#   Procesadas 17550 imágenes...
#   Procesadas 17600 imágenes...
#   Procesadas 17650 imágenes...
#   Procesadas 17700 imágenes...
#   Procesadas 17750 imágenes...
#   Procesadas 17800 imágenes...
#   Procesadas 17850 imágenes...
#   Procesadas 17900 imágenes...
#   Procesadas 17950 imágenes...
#   Procesadas 18000 imágenes...
#   Procesadas 18050 imágenes...
#   Procesadas 18100 imágenes...
#   Procesadas 18150 imágenes...
#   Procesadas 18200 imágenes...
#   Procesadas 18250 imágenes...
#   Procesadas 18300 imágenes...
#   Procesadas 18350 imágenes...
#   Procesadas 18400 imágenes...
#   Procesadas 18450 imágenes...
#   Procesadas 18500 imágenes...
#   Procesadas 18550 imágenes...
#   Procesadas 18600 imágenes...
#   Procesadas 18650 imágenes...
#   Procesadas 18700 imágenes...
#   Procesadas 18750 imágenes...
#   Procesadas 18800 imágenes...
#   Procesadas 18850 imágenes...
#   Procesadas 18900 imágenes...
#   Procesadas 18950 imágenes...
#   Procesadas 19000 imágenes...
#   Procesadas 19050 imágenes...
#   Procesadas 19100 imágenes...
#   Procesadas 19150 imágenes...
#   Procesadas 19200 imágenes...
#   Procesadas 19250 imágenes...
#   Procesadas 19300 imágenes...
#   Procesadas 19350 imágenes...
#   Procesadas 19400 imágenes...
#   Procesadas 19450 imágenes...
#   Procesadas 19500 imágenes...
#   Procesadas 19550 imágenes...
#   Procesadas 19600 imágenes...
#   Procesadas 19650 imágenes...
#   Procesadas 19700 imágenes...
#   Procesadas 19750 imágenes...
#   Procesadas 19800 imágenes...
#   Procesadas 19850 imágenes...
#   Procesadas 19900 imágenes...
#   Procesadas 19950 imágenes...
#   Procesadas 20000 imágenes...
#   Procesadas 20050 imágenes...
#   Procesadas 20100 imágenes...
#   Procesadas 20150 imágenes...
#   Procesadas 20200 imágenes...
#   Procesadas 20250 imágenes...
#   Procesadas 20300 imágenes...
#   Procesadas 20350 imágenes...
#   Procesadas 20400 imágenes...
#   Procesadas 20450 imágenes...
#   Procesadas 20500 imágenes...
#   Procesadas 20550 imágenes...
#   Procesadas 20600 imágenes...
#   Procesadas 20650 imágenes...
#   Procesadas 20700 imágenes...
#   Procesadas 20750 imágenes...
#   Procesadas 20800 imágenes...
#   Procesadas 20850 imágenes...
#   Procesadas 20900 imágenes...
#   Procesadas 20950 imágenes...
#   Procesadas 21000 imágenes...
#   Procesadas 21050 imágenes...
#   Procesadas 21100 imágenes...
#   Procesadas 21150 imágenes...
#   Procesadas 21200 imágenes...
#   Procesadas 21250 imágenes...
#   Procesadas 21300 imágenes...
#   Procesadas 21350 imágenes...
#   Procesadas 21400 imágenes...
#   Procesadas 21450 imágenes...
#   Procesadas 21500 imágenes...
#   Procesadas 21550 imágenes...
#   Procesadas 21600 imágenes...
#   Procesadas 21650 imágenes...
#   Procesadas 21700 imágenes...
#   Procesadas 21750 imágenes...
#   Procesadas 21800 imágenes...
#   Procesadas 21850 imágenes...
#   Procesadas 21900 imágenes...
#   Procesadas 21950 imágenes...
#   Procesadas 22000 imágenes...
#   Procesadas 22050 imágenes...
#   Procesadas 22100 imágenes...
#   Procesadas 22150 imágenes...
#   Procesadas 22200 imágenes...
#   Procesadas 22250 imágenes...
#   Procesadas 22300 imágenes...
#   Procesadas 22350 imágenes...
#   Procesadas 22400 imágenes...
#   Procesadas 22450 imágenes...
#   Procesadas 22500 imágenes...
#   Procesadas 22550 imágenes...
#   Procesadas 22600 imágenes...
#   ✓ Completado: 22618 imágenes procesadas
#
# Procesando carpeta: Perro
#   Procesadas 50 imágenes...
#   Procesadas 100 imágenes...
#   Procesadas 150 imágenes...
#   Procesadas 200 imágenes...
#   Procesadas 250 imágenes...
#   Procesadas 300 imágenes...
#   Procesadas 350 imágenes...
#   Procesadas 400 imágenes...
#   Procesadas 450 imágenes...
#   Procesadas 500 imágenes...
#   Procesadas 550 imágenes...
#   Procesadas 600 imágenes...
#   Procesadas 650 imágenes...
#   Procesadas 700 imágenes...
#   Procesadas 750 imágenes...
#   Procesadas 800 imágenes...
#   Procesadas 850 imágenes...
#   Procesadas 900 imágenes...
#   Procesadas 950 imágenes...
#   Procesadas 1000 imágenes...
#   Procesadas 1050 imágenes...
#   Procesadas 1100 imágenes...
#   Procesadas 1150 imágenes...
#   Procesadas 1200 imágenes...
#   Procesadas 1250 imágenes...
#   Procesadas 1300 imágenes...
#   Procesadas 1350 imágenes...
#   Procesadas 1400 imágenes...
#   Procesadas 1450 imágenes...
#   Procesadas 1500 imágenes...
#   Procesadas 1550 imágenes...
#   Procesadas 1600 imágenes...
#   Procesadas 1650 imágenes...
#   Procesadas 1700 imágenes...
#   Procesadas 1750 imágenes...
#   Procesadas 1800 imágenes...
#   Procesadas 1850 imágenes...
#   Procesadas 1900 imágenes...
#   Procesadas 1950 imágenes...
#   Procesadas 2000 imágenes...
#   Procesadas 2050 imágenes...
#   Procesadas 2100 imágenes...
#   Procesadas 2150 imágenes...
#   Procesadas 2200 imágenes...
#   Procesadas 2250 imágenes...
#   Procesadas 2300 imágenes...
#   Procesadas 2350 imágenes...
#   Procesadas 2400 imágenes...
#   Procesadas 2450 imágenes...
#   Procesadas 2500 imágenes...
#   Procesadas 2550 imágenes...
#   Procesadas 2600 imágenes...
#   Procesadas 2650 imágenes...
#   Procesadas 2700 imágenes...
#   Procesadas 2750 imágenes...
#   Procesadas 2800 imágenes...
#   Procesadas 2850 imágenes...
#   Procesadas 2900 imágenes...
#   Procesadas 2950 imágenes...
#   Procesadas 3000 imágenes...
#   Procesadas 3050 imágenes...
#   Procesadas 3100 imágenes...
#   Procesadas 3150 imágenes...
#   Procesadas 3200 imágenes...
#   Procesadas 3250 imágenes...
#   Procesadas 3300 imágenes...
#   Procesadas 3350 imágenes...
#   Procesadas 3400 imágenes...
#   Procesadas 3450 imágenes...
#   Procesadas 3500 imágenes...
#   Procesadas 3550 imágenes...
#   Procesadas 3600 imágenes...
#   Procesadas 3650 imágenes...
#   Procesadas 3700 imágenes...
#   Procesadas 3750 imágenes...
#   Procesadas 3800 imágenes...
#   Procesadas 3850 imágenes...
#   Procesadas 3900 imágenes...
#   Procesadas 3950 imágenes...
#   Procesadas 4000 imágenes...
#   Procesadas 4050 imágenes...
#   Procesadas 4100 imágenes...
#   Procesadas 4150 imágenes...
#   Procesadas 4200 imágenes...
#   Procesadas 4250 imágenes...
#   Procesadas 4300 imágenes...
#   Procesadas 4350 imágenes...
#   Procesadas 4400 imágenes...
#   Procesadas 4450 imágenes...
#   Procesadas 4500 imágenes...
#   Procesadas 4550 imágenes...
#   Procesadas 4600 imágenes...
#   Procesadas 4650 imágenes...
#   Procesadas 4700 imágenes...
#   Procesadas 4750 imágenes...
#   Procesadas 4800 imágenes...
#   Procesadas 4850 imágenes...
#   Procesadas 4900 imágenes...
#   Procesadas 4950 imágenes...
#   Procesadas 5000 imágenes...
#   Procesadas 5050 imágenes...
#   Procesadas 5100 imágenes...
#   Procesadas 5150 imágenes...
#   Procesadas 5200 imágenes...
#   Procesadas 5250 imágenes...
#   Procesadas 5300 imágenes...
#   Procesadas 5350 imágenes...
#   Procesadas 5400 imágenes...
#   Procesadas 5450 imágenes...
#   Procesadas 5500 imágenes...
#   Procesadas 5550 imágenes...
#   Procesadas 5600 imágenes...
#   Procesadas 5650 imágenes...
#   Procesadas 5700 imágenes...
#   Procesadas 5750 imágenes...
#   Procesadas 5800 imágenes...
#   Procesadas 5850 imágenes...
#   Procesadas 5900 imágenes...
#   Procesadas 5950 imágenes...
#   Procesadas 6000 imágenes...
#   Procesadas 6050 imágenes...
#   Procesadas 6100 imágenes...
#   Procesadas 6150 imágenes...
#   Procesadas 6200 imágenes...
#   Procesadas 6250 imágenes...
#   Procesadas 6300 imágenes...
#   Procesadas 6350 imágenes...
#   Procesadas 6400 imágenes...
#   Procesadas 6450 imágenes...
#   Procesadas 6500 imágenes...
#   Procesadas 6550 imágenes...
#   Procesadas 6600 imágenes...
#   Procesadas 6650 imágenes...
#   Procesadas 6700 imágenes...
#   Procesadas 6750 imágenes...
#   Procesadas 6800 imágenes...
#   Procesadas 6850 imágenes...
#   Procesadas 6900 imágenes...
#   Procesadas 6950 imágenes...
#   Procesadas 7000 imágenes...
#   Procesadas 7050 imágenes...
#   Procesadas 7100 imágenes...
#   Procesadas 7150 imágenes...
#   Procesadas 7200 imágenes...
#   Procesadas 7250 imágenes...
#   Procesadas 7300 imágenes...
#   Procesadas 7350 imágenes...
#   Procesadas 7400 imágenes...
#   Procesadas 7450 imágenes...
#   Procesadas 7500 imágenes...
#   Procesadas 7550 imágenes...
#   Procesadas 7600 imágenes...
#   Procesadas 7650 imágenes...
#   Procesadas 7700 imágenes...
#   Procesadas 7750 imágenes...
#   Procesadas 7800 imágenes...
#   Procesadas 7850 imágenes...
#   Procesadas 7900 imágenes...
#   Procesadas 7950 imágenes...
#   Procesadas 8000 imágenes...
#   Procesadas 8050 imágenes...
#   Procesadas 8100 imágenes...
#   Procesadas 8150 imágenes...
#   Procesadas 8200 imágenes...
#   Procesadas 8250 imágenes...
#   Procesadas 8300 imágenes...
#   Procesadas 8350 imágenes...
#   Procesadas 8400 imágenes...
#   Procesadas 8450 imágenes...
#   Procesadas 8500 imágenes...
#   Procesadas 8550 imágenes...
#   Procesadas 8600 imágenes...
#   Procesadas 8650 imágenes...
#   Procesadas 8700 imágenes...
#   Procesadas 8750 imágenes...
#   Procesadas 8800 imágenes...
#   Procesadas 8850 imágenes...
#   Procesadas 8900 imágenes...
#   Procesadas 8950 imágenes...
#   Procesadas 9000 imágenes...
#   Procesadas 9050 imágenes...
#   Procesadas 9100 imágenes...
#   Procesadas 9150 imágenes...
#   Procesadas 9200 imágenes...
#   Procesadas 9250 imágenes...
#   Procesadas 9300 imágenes...
#   Procesadas 9350 imágenes...
#   Procesadas 9400 imágenes...
#   Procesadas 9450 imágenes...
#   Procesadas 9500 imágenes...
#   Procesadas 9550 imágenes...
#   Procesadas 9600 imágenes...
#   Procesadas 9650 imágenes...
#   Procesadas 9700 imágenes...
#   Procesadas 9750 imágenes...
#   Procesadas 9800 imágenes...
#   Procesadas 9850 imágenes...
#   Procesadas 9900 imágenes...
#   Procesadas 9950 imágenes...
#   Procesadas 10000 imágenes...
#   Procesadas 10050 imágenes...
#   Procesadas 10100 imágenes...
#   Procesadas 10150 imágenes...
#   Procesadas 10200 imágenes...
#   Procesadas 10250 imágenes...
#   Procesadas 10300 imágenes...
#   Procesadas 10350 imágenes...
#   Procesadas 10400 imágenes...
#   Procesadas 10450 imágenes...
#   Procesadas 10500 imágenes...
#   Procesadas 10550 imágenes...
#   Procesadas 10600 imágenes...
#   Procesadas 10650 imágenes...
#   Procesadas 10700 imágenes...
#   Procesadas 10750 imágenes...
#   Procesadas 10800 imágenes...
#   Procesadas 10850 imágenes...
#   Procesadas 10900 imágenes...
#   Procesadas 10950 imágenes...
#   Procesadas 11000 imágenes...
#   Procesadas 11050 imágenes...
#   Procesadas 11100 imágenes...
#   Procesadas 11150 imágenes...
#   Procesadas 11200 imágenes...
#   Procesadas 11250 imágenes...
#   Procesadas 11300 imágenes...
# ...
#   Procesadas 16950 imágenes...
#   Procesadas 17000 imágenes...
#   Procesadas 17050 imágenes...
#   Procesadas 17100 imágenes...
#   Procesadas 17150 imágenes...
#   Procesadas 17200 imágenes...
#   Procesadas 17250 imágenes...
#   Procesadas 17300 imágenes...
#   Procesadas 17350 imágenes...
#   Procesadas 17400 imágenes...
#   Procesadas 17450 imágenes...
#   Procesadas 17500 imágenes...
#   Procesadas 17550 imágenes...
#   Procesadas 17600 imágenes...
#   Procesadas 17650 imágenes...
#   Procesadas 17700 imágenes...
#   Procesadas 17750 imágenes...
#   Procesadas 17800 imágenes...
#   Procesadas 17850 imágenes...
#   Procesadas 17900 imágenes...
#   Procesadas 17950 imágenes...
#   Procesadas 18000 imágenes...
#   Procesadas 18050 imágenes...
#   Procesadas 18100 imágenes...
#   Procesadas 18150 imágenes...
#   Procesadas 18200 imágenes...
#   Procesadas 18250 imágenes...
#   Procesadas 18300 imágenes...
#   Procesadas 18350 imágenes...
#   Procesadas 18400 imágenes...
#   Procesadas 18450 imágenes...
#   Procesadas 18500 imágenes...
#   Procesadas 18550 imágenes...
#   Procesadas 18600 imágenes...
#   Procesadas 18650 imágenes...
#   Procesadas 18700 imágenes...
#   Procesadas 18750 imágenes...
#   Procesadas 18800 imágenes...
#   Procesadas 18850 imágenes...
#   Procesadas 18900 imágenes...
#   Procesadas 18950 imágenes...
#   Procesadas 19000 imágenes...
#   Procesadas 19050 imágenes...
#   Procesadas 19100 imágenes...
#   Procesadas 19150 imágenes...
#   Procesadas 19200 imágenes...
#   Procesadas 19250 imágenes...
#   Procesadas 19300 imágenes...
#   Procesadas 19350 imágenes...
#   Procesadas 19400 imágenes...
#   Procesadas 19450 imágenes...
#   Procesadas 19500 imágenes...
#   Procesadas 19550 imágenes...
#   Procesadas 19600 imágenes...
#   Procesadas 19650 imágenes...
#   Procesadas 19700 imágenes...
#   Procesadas 19750 imágenes...
#   Procesadas 19800 imágenes...
#   Procesadas 19850 imágenes...
#   Procesadas 19900 imágenes...
#   Procesadas 19950 imágenes...
#   Procesadas 20000 imágenes...
#   Procesadas 20050 imágenes...
#   Procesadas 20100 imágenes...
#   Procesadas 20150 imágenes...
#   Procesadas 20200 imágenes...
#   Procesadas 20250 imágenes...
#   Procesadas 20300 imágenes...
#   Procesadas 20350 imágenes...
#   Procesadas 20400 imágenes...
#   ✓ Completado: 20427 imágenes procesadas
#
# Procesando carpeta: Tortuga
#   Procesadas 50 imágenes...
#   Procesadas 100 imágenes...
#   Procesadas 150 imágenes...
#   Procesadas 200 imágenes...
#   Procesadas 250 imágenes...
#   Procesadas 300 imágenes...
#   Procesadas 350 imágenes...
#   Procesadas 400 imágenes...
#   Procesadas 450 imágenes...
#   Procesadas 500 imágenes...
#   Procesadas 550 imágenes...
#   Procesadas 600 imágenes...
#   Procesadas 650 imágenes...
#   Procesadas 700 imágenes...
#   Procesadas 750 imágenes...
#   Procesadas 800 imágenes...
#   Procesadas 850 imágenes...
#   Procesadas 900 imágenes...
#   Procesadas 950 imágenes...
#   Procesadas 1000 imágenes...
#   Procesadas 1050 imágenes...
#   Procesadas 1100 imágenes...
#   Procesadas 1150 imágenes...
#   Procesadas 1200 imágenes...
#   Procesadas 1250 imágenes...
#   Procesadas 1300 imágenes...
#   Procesadas 1350 imágenes...
#   Procesadas 1400 imágenes...
#   Procesadas 1450 imágenes...
#   Procesadas 1500 imágenes...
#   Procesadas 1550 imágenes...
#   Procesadas 1600 imágenes...
#   Procesadas 1650 imágenes...
#   Procesadas 1700 imágenes...
#   Procesadas 1750 imágenes...
#   Procesadas 1800 imágenes...
#   Procesadas 1850 imágenes...
#   Procesadas 1900 imágenes...
#   Procesadas 1950 imágenes...
#   Procesadas 2000 imágenes...
#   Procesadas 2050 imágenes...
#   Procesadas 2100 imágenes...
#   Procesadas 2150 imágenes...
#   Procesadas 2200 imágenes...
#   Procesadas 2250 imágenes...
#   Procesadas 2300 imágenes...
#   Procesadas 2350 imágenes...
#   Procesadas 2400 imágenes...
#   Procesadas 2450 imágenes...
#   Procesadas 2500 imágenes...
#   Procesadas 2550 imágenes...
#   Procesadas 2600 imágenes...
#   Procesadas 2650 imágenes...
#   Procesadas 2700 imágenes...
#   Procesadas 2750 imágenes...
#   Procesadas 2800 imágenes...
#   Procesadas 2850 imágenes...
#   Procesadas 2900 imágenes...
#   Procesadas 2950 imágenes...
#   Procesadas 3000 imágenes...
#   Procesadas 3050 imágenes...
#   Procesadas 3100 imágenes...
#   Procesadas 3150 imágenes...
#   Procesadas 3200 imágenes...
#   Procesadas 3250 imágenes...
#   Procesadas 3300 imágenes...
#   Procesadas 3350 imágenes...
#   Procesadas 3400 imágenes...
#   Procesadas 3450 imágenes...
#   Procesadas 3500 imágenes...
#   Procesadas 3550 imágenes...
#   Procesadas 3600 imágenes...
#   Procesadas 3650 imágenes...
#   Procesadas 3700 imágenes...
#   Procesadas 3750 imágenes...
#   Procesadas 3800 imágenes...
#   Procesadas 3850 imágenes...
#   Procesadas 3900 imágenes...
#   Procesadas 3950 imágenes...
#   Procesadas 4000 imágenes...
#   Procesadas 4050 imágenes...
#   Procesadas 4100 imágenes...
#   Procesadas 4150 imágenes...
#   Procesadas 4200 imágenes...
#   Procesadas 4250 imágenes...
#   Procesadas 4300 imágenes...
#   Procesadas 4350 imágenes...
#   Procesadas 4400 imágenes...
#   Procesadas 4450 imágenes...
#   Procesadas 4500 imágenes...
#   Procesadas 4550 imágenes...
#   Procesadas 4600 imágenes...
#   Procesadas 4650 imágenes...
#   Procesadas 4700 imágenes...
#   Procesadas 4750 imágenes...
#   Procesadas 4800 imágenes...
#   Procesadas 4850 imágenes...
#   Procesadas 4900 imágenes...
#   Procesadas 4950 imágenes...
#   Procesadas 5000 imágenes...
#   Procesadas 5050 imágenes...
#   Procesadas 5100 imágenes...
#   Procesadas 5150 imágenes...
#   Procesadas 5200 imágenes...
#   Procesadas 5250 imágenes...
#   Procesadas 5300 imágenes...
#   Procesadas 5350 imágenes...
#   Procesadas 5400 imágenes...
#   Procesadas 5450 imágenes...
#   Procesadas 5500 imágenes...
#   Procesadas 5550 imágenes...
#   Procesadas 5600 imágenes...
#   Procesadas 5650 imágenes...
#   Procesadas 5700 imágenes...
#   Procesadas 5750 imágenes...
#   Procesadas 5800 imágenes...
#   Procesadas 5850 imágenes...
#   Procesadas 5900 imágenes...
#   Procesadas 5950 imágenes...
#   Procesadas 6000 imágenes...
#   Procesadas 6050 imágenes...
#   Procesadas 6100 imágenes...
#   Procesadas 6150 imágenes...
#   Procesadas 6200 imágenes...
#   Procesadas 6250 imágenes...
#   Procesadas 6300 imágenes...
#   Procesadas 6350 imágenes...
#   Procesadas 6400 imágenes...
#   Procesadas 6450 imágenes...
#   Procesadas 6500 imágenes...
#   Procesadas 6550 imágenes...
#   Procesadas 6600 imágenes...
#   Procesadas 6650 imágenes...
#   Procesadas 6700 imágenes...
#   Procesadas 6750 imágenes...
#   Procesadas 6800 imágenes...
#   Procesadas 6850 imágenes...
#   Procesadas 6900 imágenes...
#   Procesadas 6950 imágenes...
#   Procesadas 7000 imágenes...
#   Procesadas 7050 imágenes...
#   Procesadas 7100 imágenes...
#   Procesadas 7150 imágenes...
#   Procesadas 7200 imágenes...
#   Procesadas 7250 imágenes...
#   Procesadas 7300 imágenes...
#   Procesadas 7350 imágenes...
#   Procesadas 7400 imágenes...
#   Procesadas 7450 imágenes...
#   Procesadas 7500 imágenes...
#   Procesadas 7550 imágenes...
#   Procesadas 7600 imágenes...
#   Procesadas 7650 imágenes...
#   Procesadas 7700 imágenes...
#   Procesadas 7750 imágenes...
#   Procesadas 7800 imágenes...
#   Procesadas 7850 imágenes...
#   Procesadas 7900 imágenes...
#   Procesadas 7950 imágenes...
#   Procesadas 8000 imágenes...
#   Procesadas 8050 imágenes...
#   Procesadas 8100 imágenes...
#   Procesadas 8150 imágenes...
#   Procesadas 8200 imágenes...
#   Procesadas 8250 imágenes...
#   Procesadas 8300 imágenes...
#   Procesadas 8350 imágenes...
#   Procesadas 8400 imágenes...
#   Procesadas 8450 imágenes...
#   Procesadas 8500 imágenes...
#   Procesadas 8550 imágenes...
#   Procesadas 8600 imágenes...
#   Procesadas 8650 imágenes...
#   Procesadas 8700 imágenes...
#   Procesadas 8750 imágenes...
#   Procesadas 8800 imágenes...
#   Procesadas 8850 imágenes...
#   Procesadas 8900 imágenes...
#   Procesadas 8950 imágenes...
#   Procesadas 9000 imágenes...
#   Procesadas 9050 imágenes...
#   Procesadas 9100 imágenes...
#   Procesadas 9150 imágenes...
#   Procesadas 9200 imágenes...
#   Procesadas 9250 imágenes...
#   Procesadas 9300 imágenes...
#   Procesadas 9350 imágenes...
#   Procesadas 9400 imágenes...
#   Procesadas 9450 imágenes...
#   Procesadas 9500 imágenes...
#   Procesadas 9550 imágenes...
#   Procesadas 9600 imágenes...
#   Procesadas 9650 imágenes...
#   Procesadas 9700 imágenes...
#   Procesadas 9750 imágenes...
#   Procesadas 9800 imágenes...
#   Procesadas 9850 imágenes...
#   Procesadas 9900 imágenes...
#   Procesadas 9950 imágenes...
#   Procesadas 10000 imágenes...
#   Procesadas 10050 imágenes...
#   Procesadas 10100 imágenes...
#   Procesadas 10150 imágenes...
#   Procesadas 10200 imágenes...
#   Procesadas 10250 imágenes...
#   Procesadas 10300 imágenes...
#   Procesadas 10350 imágenes...
#   Procesadas 10400 imágenes...
#   Procesadas 10450 imágenes...
#   Procesadas 10500 imágenes...
#   Procesadas 10550 imágenes...
#   Procesadas 10600 imágenes...
#   Procesadas 10650 imágenes...
#   Procesadas 10700 imágenes...
#   Procesadas 10750 imágenes...
#   Procesadas 10800 imágenes...
#   Procesadas 10850 imágenes...
#   Procesadas 10900 imágenes...
#   Procesadas 10950 imágenes...
#   Procesadas 11000 imágenes...
#   Procesadas 11050 imágenes...
#   Procesadas 11100 imágenes...
#   Procesadas 11150 imágenes...
#   Procesadas 11200 imágenes...
#   Procesadas 11250 imágenes...
#   Procesadas 11300 imágenes...
#   Procesadas 11350 imágenes...
#   Procesadas 11400 imágenes...
#   Procesadas 11450 imágenes...
#   Procesadas 11500 imágenes...
#   Procesadas 11550 imágenes...
#   Procesadas 11600 imágenes...
#   Procesadas 11650 imágenes...
#   Procesadas 11700 imágenes...
#   Procesadas 11750 imágenes...
#   Procesadas 11800 imágenes...
#   Procesadas 11850 imágenes...
#   Procesadas 11900 imágenes...
#   Procesadas 11950 imágenes...
#   Procesadas 12000 imágenes...
#   Procesadas 12050 imágenes...
#   Procesadas 12100 imágenes...
#   Procesadas 12150 imágenes...
#   Procesadas 12200 imágenes...
#   Procesadas 12250 imágenes...
#   Procesadas 12300 imágenes...
#   Procesadas 12350 imágenes...
#   Procesadas 12400 imágenes...
#   Procesadas 12450 imágenes...
#   Procesadas 12500 imágenes...
#   Procesadas 12550 imágenes...
#   Procesadas 12600 imágenes...
#   Procesadas 12650 imágenes...
#   Procesadas 12700 imágenes...
#   Procesadas 12750 imágenes...
#   Procesadas 12800 imágenes...
#   Procesadas 12850 imágenes...
#   Procesadas 12900 imágenes...
#   Procesadas 12950 imágenes...
#   Procesadas 13000 imágenes...
#   Procesadas 13050 imágenes...
#   Procesadas 13100 imágenes...
#   Procesadas 13150 imágenes...
#   Procesadas 13200 imágenes...
#   Procesadas 13250 imágenes...
#   Procesadas 13300 imágenes...
#   Procesadas 13350 imágenes...
#   Procesadas 13400 imágenes...
#   Procesadas 13450 imágenes...
#   Procesadas 13500 imágenes...
#   Procesadas 13550 imágenes...
#   Procesadas 13600 imágenes...
#   Procesadas 13650 imágenes...
#   Procesadas 13700 imágenes...
#   Procesadas 13750 imágenes...
#   Procesadas 13800 imágenes...
#   Procesadas 13850 imágenes...
#   Procesadas 13900 imágenes...
#   Procesadas 13950 imágenes...
#   Procesadas 14000 imágenes...
#   Procesadas 14050 imágenes...
#   Procesadas 14100 imágenes...
#   Procesadas 14150 imágenes...
#   Procesadas 14200 imágenes...
#   Procesadas 14250 imágenes...
#   Procesadas 14300 imágenes...
#   Procesadas 14350 imágenes...
#   Procesadas 14400 imágenes...
#   Procesadas 14450 imágenes...
#   Procesadas 14500 imágenes...
#   Procesadas 14550 imágenes...
#   Procesadas 14600 imágenes...
#   Procesadas 14650 imágenes...
#   Procesadas 14700 imágenes...
#   Procesadas 14750 imágenes...
#   Procesadas 14800 imágenes...
#   Procesadas 14850 imágenes...
#   Procesadas 14900 imágenes...
#   Procesadas 14950 imágenes...
#   Procesadas 15000 imágenes...
#   Procesadas 15050 imágenes...
#   Procesadas 15100 imágenes...
#   Procesadas 15150 imágenes...
#   Procesadas 15200 imágenes...
#   Procesadas 15250 imágenes...
#   Procesadas 15300 imágenes...
#   Procesadas 15350 imágenes...
#   Procesadas 15400 imágenes...
#   Procesadas 15450 imágenes...
#   Procesadas 15500 imágenes...
#   Procesadas 15550 imágenes...
#   Procesadas 15600 imágenes...
#   Procesadas 15650 imágenes...
#   Procesadas 15700 imágenes...
#   Procesadas 15750 imágenes...
#   Procesadas 15800 imágenes...
#   Procesadas 15850 imágenes...
#   Procesadas 15900 imágenes...
#   Procesadas 15950 imágenes...
#   Procesadas 16000 imágenes...
#   Procesadas 16050 imágenes...
#   Procesadas 16100 imágenes...
#   Procesadas 16150 imágenes...
#   Procesadas 16200 imágenes...
#   Procesadas 16250 imágenes...
#   Procesadas 16300 imágenes...
#   Procesadas 16350 imágenes...
#   Procesadas 16400 imágenes...
#   Procesadas 16450 imágenes...
#   Procesadas 16500 imágenes...
#   Procesadas 16550 imágenes...
#   Procesadas 16600 imágenes...
#   Procesadas 16650 imágenes...
#   Procesadas 16700 imágenes...
#   Procesadas 16750 imágenes...
#   Procesadas 16800 imágenes...
#   Procesadas 16850 imágenes...
#   Procesadas 16900 imágenes...
#   Procesadas 16950 imágenes...
#   Procesadas 17000 imágenes...
#   Procesadas 17050 imágenes...
#   Procesadas 17100 imágenes...
#   Procesadas 17150 imágenes...
#   Procesadas 17200 imágenes...
#   Procesadas 17250 imágenes...
#   Procesadas 17300 imágenes...
#   Procesadas 17350 imágenes...
#   Procesadas 17400 imágenes...
#   Procesadas 17450 imágenes...
#   Procesadas 17500 imágenes...
#   Procesadas 17550 imágenes...
#   Procesadas 17600 imágenes...
#   Procesadas 17650 imágenes...
#   Procesadas 17700 imágenes...
#   Procesadas 17750 imágenes...
#   Procesadas 17800 imágenes...
#   Procesadas 17850 imágenes...
#   Procesadas 17900 imágenes...
#   Procesadas 17950 imágenes...
#   Procesadas 18000 imágenes...
#   Procesadas 18050 imágenes...
#   Procesadas 18100 imágenes...
#   Procesadas 18150 imágenes...
#   Procesadas 18200 imágenes...
#   Procesadas 18250 imágenes...
#   Procesadas 18300 imágenes...
#   Procesadas 18350 imágenes...
#   Procesadas 18400 imágenes...
#   Procesadas 18450 imágenes...
#   Procesadas 18500 imágenes...
#   Procesadas 18550 imágenes...
#   Procesadas 18600 imágenes...
#   Procesadas 18650 imágenes...
#   Procesadas 18700 imágenes...
#   Procesadas 18750 imágenes...
#   Procesadas 18800 imágenes...
#   Procesadas 18850 imágenes...
#   Procesadas 18900 imágenes...
#   Procesadas 18950 imágenes...
#   Procesadas 19000 imágenes...
#   Procesadas 19050 imágenes...
#   Procesadas 19100 imágenes...
#   Procesadas 19150 imágenes...
#   Procesadas 19200 imágenes...
#   Procesadas 19250 imágenes...
#   Procesadas 19300 imágenes...
#   Procesadas 19350 imágenes...
#   Procesadas 19400 imágenes...
#   Procesadas 19450 imágenes...
#   Procesadas 19500 imágenes...
#   Procesadas 19550 imágenes...
#   Procesadas 19600 imágenes...
#   Procesadas 19650 imágenes...
#   Procesadas 19700 imágenes...
#   Procesadas 19750 imágenes...
#   Procesadas 19800 imágenes...
#   Procesadas 19850 imágenes...
#   Procesadas 19900 imágenes...
#   Procesadas 19950 imágenes...
#   Procesadas 20000 imágenes...
#   Procesadas 20050 imágenes...
#   Procesadas 20100 imágenes...
#   Procesadas 20150 imágenes...
#   Procesadas 20200 imágenes...
#   Procesadas 20250 imágenes...
#   Procesadas 20300 imágenes...
#   Procesadas 20350 imágenes...
#   Procesadas 20400 imágenes...
#   Procesadas 20450 imágenes...
#   Procesadas 20500 imágenes...
#   Procesadas 20550 imágenes...
#   Procesadas 20600 imágenes...
#   Procesadas 20650 imágenes...
#   Procesadas 20700 imágenes...
#   Procesadas 20750 imágenes...
#   Procesadas 20800 imágenes...
#   Procesadas 20850 imágenes...
#   Procesadas 20900 imágenes...
#   Procesadas 20950 imágenes...
#   Procesadas 21000 imágenes...
#   Procesadas 21050 imágenes...
#   Procesadas 21100 imágenes...
#   Procesadas 21150 imágenes...
#   Procesadas 21200 imágenes...
#   Procesadas 21250 imágenes...
#   Procesadas 21300 imágenes...
#   Procesadas 21350 imágenes...
#   Procesadas 21400 imágenes...
#   Procesadas 21450 imágenes...
#   Procesadas 21500 imágenes...
#   Procesadas 21550 imágenes...
#   Procesadas 21600 imágenes...
#   Procesadas 21650 imágenes...
#   Procesadas 21700 imágenes...
#   Procesadas 21750 imágenes...
#   Procesadas 21800 imágenes...
#   Procesadas 21850 imágenes...
#   ✓ Completado: 21864 imágenes procesadas
#
# ==================================================
# Proceso completado:
#   Total de imágenes procesadas: 109439
#   Errores encontrados: 0
#   Tamaño final: (96, 96)
#   Dataset guardado en: C:\Datasets\DatasetsAi_Resized\DatasetsAi_Resized_96x96
# ==================================================
#
# ¡Listo! Ahora puedes usar el dataset redimensionado para entrenar tu CNN.

# %%
# Celda 1: Importar Librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re # Para expresiones regulares en NLP

# Configuración de visualización (opcional)
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Celda 2: Cargar el Dataset
try:
    df = pd.read_csv('dataset_sintetico_5000_ampliado.csv')
except FileNotFoundError:
    print("Error: Asegúrate de que el archivo 'analisis_temas.csv' esté en la misma carpeta.")

# %%
df
# Out:
#         id       fecha     usuario  \
# 0        1  2022-05-01  user_44220
# 1        2  2024-03-21   user_8463
# 2        3  2022-12-21  user_26421
# 3        4  2022-09-04  user_24985
# 4        5  2022-01-15  user_71752
# ...    ...         ...         ...
# 4995  4996  2024-01-06  user_69059
# 4996  4997  2023-02-27    user_711
# 4997  4998  2022-01-12  user_41449
# 4998  4999  2024-04-29  user_38388
# 4999  5000  2023-12-14  user_80621
#
#                                                   texto  \
# 0     La presión por ser productivo todo el tiempo e...
# 1     Antes los proyectos de vida eran a largo plazo...
# 2     Cada vez que una app me recomienda qué ver o q...
# 3     Todo se mueve tan rápido que incluso los recue...
# 4     ¿Seguimos siendo sujetos libres si los algorit...
# ...                                                 ...
# 4995  La Generación Z enfrenta un dilema existencial...
# 4996  Todo se mueve tan rápido que incluso los recue...
# 4997  Cada vez que una app me recomienda qué ver o q...
# 4998  Los algoritmos parecen conocer mis gustos mejo...
# 4999  El ruido constante de las redes sociales hace ...
#
#                                            tema sentimiento  likes  reposts
# 0              Generación Z y crisis de sentido     neutral   1056     2652
# 1     Cultura de lo efímero y proyectos de vida     neutral   4032      566
# 2     Cultura de lo efímero y proyectos de vida     neutral   7884     1817
# 3     Cultura de lo efímero y proyectos de vida     neutral   8695     3614
# 4     Cultura de lo efímero y proyectos de vida    negativo  16384     2610
# ...                                         ...         ...    ...      ...
# 4995           IA y pérdida de autonomía humana     neutral   2617     1998
# 4996           IA y pérdida de autonomía humana     neutral  10728     1707
# 4997           IA y pérdida de autonomía humana    negativo  13648      863
# 4998  Cultura de lo efímero y proyectos de vida    positivo  12331     1688
# 4999           Generación Z y crisis de sentido    negativo   9799     2814
#
# [5000 rows x 8 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
# %config IPCompleter.greedy=True

# %%
data = df['texto'].head(100)
data
# Out:
# 0     La presión por ser productivo todo el tiempo e...
# 1     Antes los proyectos de vida eran a largo plazo...
# 2     Cada vez que una app me recomienda qué ver o q...
# 3     Todo se mueve tan rápido que incluso los recue...
# 4     ¿Seguimos siendo sujetos libres si los algorit...
#                             ...
# 95    Los algoritmos parecen conocer mis gustos mejo...
# 96    Los vínculos afectivos hoy son más frágiles qu...
# 97    Muchos jóvenes sienten que el futuro es incier...
# 98    A veces siento que la presión de mostrar una v...
# 99    La Generación Z enfrenta un dilema existencial...
# Name: texto, Length: 100, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

count_vectorizer = CountVectorizer(stop_words = 'spanish')
count_vectorizer = CountVectorizer()
matrix = count_vectorizer.fit_transform(data)
data_matrix = matrix.todense()
data_matrix
frecuencias = pd.DataFrame(data_matrix, columns=count_vectorizer.get_feature_names_out())
frecuencias
salida = cosine_similarity (frecuencias, frecuencias)
salida
# Out:
# array([[1.        , 0.08399211, 0.03849002, ..., 0.14814815, 0.40164272,
#         0.22075539],
#        [0.08399211, 1.        , 0.13093073, ..., 0.16798421, 0.19518001,
#         0.10012523],
#        [0.03849002, 0.13093073, 1.        , ..., 0.23094011, 0.23851392,
#         0.09176629],
#        ...,
#        [0.14814815, 0.16798421, 0.23094011, ..., 1.        , 0.22951012,
#         0.13245324],
#        [0.40164272, 0.19518001, 0.23851392, ..., 0.22951012, 1.        ,
#         0.30779351],
#        [0.22075539, 0.10012523, 0.09176629, ..., 0.13245324, 0.30779351,
#         1.        ]])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.imshow(salida)
plt.colorbar()

# %%
umbral = 0.70 

pares_similares = []

for i in range(len(data)):
    for j in range(i + 1, len(data)):   # evitar duplicados y no comparar consigo mismo
        score = salida[i][j]
        if score >= umbral:
            pares_similares.append((i, j, score))

# Si no hay resultados
if not pares_similares:
    print(f"No hay pares con similitud mayor a {umbral}.")
else:
    print(f"Pares con similitud >= {umbral}:\n")
    for i, j, score in pares_similares:
        print(f"\n======================================")
        print(f"🔗 Par ({i+1}, {j+1}) - Similitud: {score:.4f}")
        print(f"📝 Texto {i+1}: {data.iloc[i]}")
        print(f"📝 Texto {j+1}: {data.iloc[j]}")
# Out:
# Pares con similitud >= 0.7:
#
#
# ======================================
# 🔗 Par (1, 14) - Similitud: 1.0000
# 📝 Texto 1: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 14: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
#
# ======================================
# 🔗 Par (1, 21) - Similitud: 0.8056
# 📝 Texto 1: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 21: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible. La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
#
# ======================================
# 🔗 Par (1, 22) - Similitud: 0.8248
# 📝 Texto 1: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 22: La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad? La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
#
# ======================================
# 🔗 Par (1, 28) - Similitud: 0.7877
# 📝 Texto 1: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 28: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (1, 76) - Similitud: 0.7877
# 📝 Texto 1: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 76: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (2, 7) - Similitud: 1.0000
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (2, 8) - Similitud: 1.0000
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (2, 13) - Similitud: 0.7290
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
#
# ======================================
# 🔗 Par (2, 42) - Similitud: 1.0000
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 42: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (2, 47) - Similitud: 0.7698
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 47: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (2, 54) - Similitud: 1.0000
# 📝 Texto 2: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 54: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (3, 12) - Similitud: 1.0000
# 📝 Texto 3: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
# 📝 Texto 12: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
#
# ======================================
# 🔗 Par (3, 35) - Similitud: 1.0000
# 📝 Texto 3: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
# 📝 Texto 35: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
#
# ======================================
# 🔗 Par (4, 17) - Similitud: 1.0000
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (4, 37) - Similitud: 0.7743
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 37: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (4, 47) - Similitud: 0.8333
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 47: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (4, 57) - Similitud: 1.0000
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 57: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (4, 71) - Similitud: 0.7985
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (4, 88) - Similitud: 0.7388
# 📝 Texto 4: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 88: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (5, 11) - Similitud: 1.0000
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (5, 18) - Similitud: 1.0000
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (5, 38) - Similitud: 1.0000
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 38: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (5, 59) - Similitud: 1.0000
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 59: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (5, 77) - Similitud: 1.0000
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 77: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (5, 89) - Similitud: 0.7778
# 📝 Texto 5: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 89: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece? La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (6, 9) - Similitud: 1.0000
# 📝 Texto 6: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 9: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (6, 25) - Similitud: 1.0000
# 📝 Texto 6: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 25: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (6, 32) - Similitud: 1.0000
# 📝 Texto 6: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 32: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (6, 46) - Similitud: 1.0000
# 📝 Texto 6: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 46: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (6, 74) - Similitud: 1.0000
# 📝 Texto 6: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 74: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (7, 8) - Similitud: 1.0000
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (7, 13) - Similitud: 0.7290
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
#
# ======================================
# 🔗 Par (7, 42) - Similitud: 1.0000
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 42: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (7, 47) - Similitud: 0.7698
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 47: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (7, 54) - Similitud: 1.0000
# 📝 Texto 7: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 54: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (8, 13) - Similitud: 0.7290
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
#
# ======================================
# 🔗 Par (8, 42) - Similitud: 1.0000
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 42: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (8, 47) - Similitud: 0.7698
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 47: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (8, 54) - Similitud: 1.0000
# 📝 Texto 8: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
# 📝 Texto 54: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (9, 25) - Similitud: 1.0000
# 📝 Texto 9: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 25: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (9, 32) - Similitud: 1.0000
# 📝 Texto 9: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 32: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (9, 46) - Similitud: 1.0000
# 📝 Texto 9: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 46: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (9, 74) - Similitud: 1.0000
# 📝 Texto 9: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 74: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (10, 30) - Similitud: 1.0000
# 📝 Texto 10: El ruido constante de las redes sociales hace difícil encontrar silencio interior. ¿Cómo pensar profundamente en medio de tantas distracciones?
# 📝 Texto 30: El ruido constante de las redes sociales hace difícil encontrar silencio interior. ¿Cómo pensar profundamente en medio de tantas distracciones?
#
# ======================================
# 🔗 Par (10, 93) - Similitud: 1.0000
# 📝 Texto 10: El ruido constante de las redes sociales hace difícil encontrar silencio interior. ¿Cómo pensar profundamente en medio de tantas distracciones?
# 📝 Texto 93: El ruido constante de las redes sociales hace difícil encontrar silencio interior. ¿Cómo pensar profundamente en medio de tantas distracciones?
#
# ======================================
# 🔗 Par (11, 18) - Similitud: 1.0000
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (11, 38) - Similitud: 1.0000
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 38: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (11, 59) - Similitud: 1.0000
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 59: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (11, 77) - Similitud: 1.0000
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 77: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (11, 89) - Similitud: 0.7778
# 📝 Texto 11: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 89: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece? La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (12, 35) - Similitud: 1.0000
# 📝 Texto 12: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
# 📝 Texto 35: Cada vez que una app me recomienda qué ver o qué comprar, siento que renuncio un poco más a mi libertad de elección.
#
# ======================================
# 🔗 Par (13, 42) - Similitud: 0.7290
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
# 📝 Texto 42: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (13, 54) - Similitud: 0.7290
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
# 📝 Texto 54: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (13, 92) - Similitud: 0.7972
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
# 📝 Texto 92: Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
#
# ======================================
# 🔗 Par (13, 98) - Similitud: 0.7972
# 📝 Texto 13: Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok. Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
# 📝 Texto 98: Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
#
# ======================================
# 🔗 Par (14, 21) - Similitud: 0.8056
# 📝 Texto 14: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 21: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible. La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
#
# ======================================
# 🔗 Par (14, 22) - Similitud: 0.8248
# 📝 Texto 14: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 22: La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad? La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
#
# ======================================
# 🔗 Par (14, 28) - Similitud: 0.7877
# 📝 Texto 14: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 28: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (14, 76) - Similitud: 0.7877
# 📝 Texto 14: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 76: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (15, 26) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 26: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 34) - Similitud: 0.7672
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 34: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
#
# ======================================
# 🔗 Par (15, 44) - Similitud: 0.7343
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 44: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 45) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 45: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 63) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 63: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 72) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 72: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 86) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 86: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (15, 99) - Similitud: 0.8500
# 📝 Texto 15: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 99: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (16, 19) - Similitud: 1.0000
# 📝 Texto 16: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
# 📝 Texto 19: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
#
# ======================================
# 🔗 Par (16, 75) - Similitud: 0.7715
# 📝 Texto 16: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
# 📝 Texto 75: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (16, 100) - Similitud: 1.0000
# 📝 Texto 16: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
# 📝 Texto 100: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
#
# ======================================
# 🔗 Par (17, 37) - Similitud: 0.7743
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 37: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (17, 47) - Similitud: 0.8333
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 47: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Antes los proyectos de vida eran a largo plazo; hoy parece que nuestra identidad cambia tan rápido como las tendencias en TikTok.
#
# ======================================
# 🔗 Par (17, 57) - Similitud: 1.0000
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 57: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (17, 71) - Similitud: 0.7985
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (17, 88) - Similitud: 0.7388
# 📝 Texto 17: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 88: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (18, 38) - Similitud: 1.0000
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 38: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (18, 59) - Similitud: 1.0000
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 59: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (18, 77) - Similitud: 1.0000
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 77: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
#
# ======================================
# 🔗 Par (18, 89) - Similitud: 0.7778
# 📝 Texto 18: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 89: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece? La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (19, 75) - Similitud: 0.7715
# 📝 Texto 19: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
# 📝 Texto 75: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (19, 100) - Similitud: 1.0000
# 📝 Texto 19: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
# 📝 Texto 100: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
#
# ======================================
# 🔗 Par (20, 29) - Similitud: 1.0000
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 29: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
#
# ======================================
# 🔗 Par (20, 39) - Similitud: 0.8165
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 39: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (20, 44) - Similitud: 0.7424
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 44: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (20, 58) - Similitud: 1.0000
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 58: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
#
# ======================================
# 🔗 Par (20, 67) - Similitud: 1.0000
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 67: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
#
# ======================================
# 🔗 Par (20, 73) - Similitud: 0.7715
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 73: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
#
# ======================================
# 🔗 Par (20, 95) - Similitud: 0.8248
# 📝 Texto 20: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 95: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (22, 28) - Similitud: 0.7265
# 📝 Texto 22: La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad? La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 28: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (22, 76) - Similitud: 0.7265
# 📝 Texto 22: La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad? La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento.
# 📝 Texto 76: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (23, 36) - Similitud: 0.7682
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 36: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (23, 37) - Similitud: 0.7426
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 37: Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure. Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (23, 55) - Similitud: 1.0000
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 55: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (23, 65) - Similitud: 0.8168
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 65: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (23, 68) - Similitud: 1.0000
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 68: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (23, 70) - Similitud: 1.0000
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 70: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (23, 94) - Similitud: 1.0000
# 📝 Texto 23: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 94: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (24, 56) - Similitud: 1.0000
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 56: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (24, 62) - Similitud: 1.0000
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 62: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (24, 71) - Similitud: 0.7475
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (24, 80) - Similitud: 1.0000
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 80: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (24, 84) - Similitud: 1.0000
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 84: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (24, 87) - Similitud: 1.0000
# 📝 Texto 24: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 87: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (25, 32) - Similitud: 1.0000
# 📝 Texto 25: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 32: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (25, 46) - Similitud: 1.0000
# 📝 Texto 25: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 46: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (25, 74) - Similitud: 1.0000
# 📝 Texto 25: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
# 📝 Texto 74: Estamos tan acostumbrados a la recompensa instantánea que cualquier proyecto que requiera paciencia nos parece imposible.
#
# ======================================
# 🔗 Par (26, 34) - Similitud: 0.8794
# 📝 Texto 26: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
# 📝 Texto 34: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación. Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
#
# ======================================
# 🔗 Par (26, 44) - Similitud: 0.8548
# 📝 Texto 26: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
# 📝 Texto 44: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (26, 45) - Similitud: 1.0000
# ...
# 📝 Texto 70: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (65, 94) - Similitud: 0.8168
# 📝 Texto 65: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
# 📝 Texto 94: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (66, 69) - Similitud: 1.0000
# 📝 Texto 66: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
# 📝 Texto 69: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
#
# ======================================
# 🔗 Par (66, 88) - Similitud: 0.7680
# 📝 Texto 66: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
# 📝 Texto 88: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (66, 96) - Similitud: 1.0000
# 📝 Texto 66: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
# 📝 Texto 96: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
#
# ======================================
# 🔗 Par (67, 73) - Similitud: 0.7715
# 📝 Texto 67: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 73: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
#
# ======================================
# 🔗 Par (67, 95) - Similitud: 0.8248
# 📝 Texto 67: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida.
# 📝 Texto 95: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (68, 70) - Similitud: 1.0000
# 📝 Texto 68: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 70: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (68, 94) - Similitud: 1.0000
# 📝 Texto 68: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 94: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (69, 88) - Similitud: 0.7680
# 📝 Texto 69: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
# 📝 Texto 88: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
#
# ======================================
# 🔗 Par (69, 96) - Similitud: 1.0000
# 📝 Texto 69: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
# 📝 Texto 96: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
#
# ======================================
# 🔗 Par (70, 94) - Similitud: 1.0000
# 📝 Texto 70: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
# 📝 Texto 94: Muchos jóvenes tienen una sensación de vacío difícil de explicar. Vivimos en un mundo hiperconectado, pero paradójicamente, cada día nos sentimos más solos.
#
# ======================================
# 🔗 Par (71, 80) - Similitud: 0.7475
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 80: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (71, 84) - Similitud: 0.7475
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 84: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (71, 87) - Similitud: 0.7475
# 📝 Texto 71: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 87: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (72, 86) - Similitud: 1.0000
# 📝 Texto 72: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
# 📝 Texto 86: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (72, 99) - Similitud: 1.0000
# 📝 Texto 72: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
# 📝 Texto 99: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (73, 78) - Similitud: 0.7245
# 📝 Texto 73: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
# 📝 Texto 78: La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
#
# ======================================
# 🔗 Par (73, 85) - Similitud: 0.7245
# 📝 Texto 73: No sé si la tecnología nos está liberando del esfuerzo o si nos está convirtiendo en espectadores pasivos de nuestra propia vida. La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
# 📝 Texto 85: La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
#
# ======================================
# 🔗 Par (75, 100) - Similitud: 0.7715
# 📝 Texto 75: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante. La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
# 📝 Texto 100: La Generación Z enfrenta un dilema existencial: querer cambiar el mundo, pero estar atrapada en dinámicas de inmediatez y consumo constante.
#
# ======================================
# 🔗 Par (76, 82) - Similitud: 0.7784
# 📝 Texto 76: La presión por ser productivo todo el tiempo está quemando a una generación entera. No todo en la vida debe ser rendimiento. Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
# 📝 Texto 82: Con tanta información, el desafío ya no es aprender, sino filtrar. El exceso de conocimiento puede ser una forma moderna de confusión.
#
# ======================================
# 🔗 Par (77, 89) - Similitud: 0.7778
# 📝 Texto 77: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece?
# 📝 Texto 89: ¿Seguimos siendo sujetos libres si los algoritmos determinan qué contenido vemos y qué contenido nunca nos aparece? La IA puede predecir nuestras emociones con una precisión inquietante. ¿Qué queda entonces de nuestra espontaneidad?
#
# ======================================
# 🔗 Par (78, 85) - Similitud: 1.0000
# 📝 Texto 78: La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
# 📝 Texto 85: La Generación Z ha heredado un mundo acelerado, caótico y saturado. Buscar sentido en medio de ese ruido es un acto filosófico profundo.
#
# ======================================
# 🔗 Par (79, 81) - Similitud: 1.0000
# 📝 Texto 79: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
# 📝 Texto 81: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
#
# ======================================
# 🔗 Par (79, 97) - Similitud: 1.0000
# 📝 Texto 79: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
# 📝 Texto 97: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
#
# ======================================
# 🔗 Par (80, 84) - Similitud: 1.0000
# 📝 Texto 80: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 84: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (80, 87) - Similitud: 1.0000
# 📝 Texto 80: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 87: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (81, 97) - Similitud: 1.0000
# 📝 Texto 81: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
# 📝 Texto 97: Los vínculos afectivos hoy son más frágiles que nunca. La inmediatez también afecta las relaciones humanas.
#
# ======================================
# 🔗 Par (83, 90) - Similitud: 1.0000
# 📝 Texto 83: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
# 📝 Texto 90: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
#
# ======================================
# 🔗 Par (83, 91) - Similitud: 1.0000
# 📝 Texto 83: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
# 📝 Texto 91: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
#
# ======================================
# 🔗 Par (84, 87) - Similitud: 1.0000
# 📝 Texto 84: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
# 📝 Texto 87: La cultura actual parece obsesionada con lo nuevo y lo inmediato, dejando poco espacio para la reflexión o el compromiso duradero.
#
# ======================================
# 🔗 Par (86, 99) - Similitud: 1.0000
# 📝 Texto 86: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
# 📝 Texto 99: A veces siento que la presión de mostrar una vida perfecta en redes sociales nos roba la oportunidad de ser auténticos. La Generación Z vive entre expectativas irreales y una búsqueda constante de validación.
#
# ======================================
# 🔗 Par (88, 96) - Similitud: 0.7680
# 📝 Texto 88: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento. Todo se mueve tan rápido que incluso los recuerdos parecen caducar. La cultura de lo efímero borra cualquier intento de construir algo que perdure.
# 📝 Texto 96: Los algoritmos parecen conocer mis gustos mejor que yo mismo. Es inquietante pensar si realmente sigo mis propias decisiones o si son las plataformas quienes moldean mi comportamiento.
#
# ======================================
# 🔗 Par (90, 91) - Similitud: 1.0000
# 📝 Texto 90: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
# 📝 Texto 91: La relación entre la inteligencia artificial y nuestra autonomía se está volviendo difusa. ¿Hasta qué punto delegamos decisiones importantes sin darnos cuenta?
#
# ======================================
# 🔗 Par (92, 98) - Similitud: 1.0000
# 📝 Texto 92: Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.
# 📝 Texto 98: Muchos jóvenes sienten que el futuro es incierto, no por falta de oportunidades, sino por exceso de opciones que terminan paralizando.

# %% [markdown]
# ### Análisis Temporal y Visualización de la Cobertura (Celda 4)
# Analizaremos la intensidad de la cobertura noticiosa simulada a lo largo del tiempo, combinando ambos temas.

# %%
# Celda 4: Análisis Temporal
# 1. Agrupar el conteo de registros por día
cobertura_diaria = df.groupby(df['Fecha'].dt.date)['ID'].count().reset_index()
cobertura_diaria.columns = ['Fecha', 'Conteo']

# 2. Visualización: Cobertura de la Noticia por Día 
#[Image of a line chart showing daily news coverage count over time]

plt.figure(figsize=(12, 5))
sns.lineplot(data=cobertura_diaria, x='Fecha', y='Conteo', marker='o')
plt.title('Tendencia de la Cobertura Noticiosa (Simulada)')
plt.xlabel('Fecha')
plt.ylabel('Número de Registros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Cobertura por Día de la Semana
df['Dia_Semana'] = df['Fecha'].dt.day_name()
conteo_dias = df['Dia_Semana'].value_counts().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']).fillna(0)
print("\n--- Conteo por Día de la Semana ---\n", conteo_dias)
# Out:
# --- Conteo por Día de la Semana ---
#  Monday       36
# Tuesday      32
# Wednesday    16
# Thursday     20
# Friday       24
# Saturday     34
# Sunday       38
# Name: Dia_Semana, dtype: int64

# %% [markdown]
# ### Procesamiento Básico de Lenguaje Natural (NLP) (Celdas 5-6)
#
# Para entender mejor las narrativas, extraemos las palabras más frecuentes en los comentarios de cada categoría.

# %%
# Celda 5: Top Palabras Clave (Generación Z)
# 1. Filtrar el texto y combinar Comentarios/Resúmenes de Gen Z
texto_genz = ' '.join(df[df['Categoria'] == 'Generacion Z']['Comentario_Reaccion'].astype(str) + ' ' +
                      df[df['Categoria'] == 'Generacion Z']['Resumen'].astype(str))

# 2. Tokenización y limpieza básica (remover puntuación y números)
texto_limpio = re.sub(r'[^\w\s]', '', texto_genz.lower())
palabras = texto_limpio.split()

# 3. Definir Stopwords (palabras comunes que no añaden valor)
stopwords_es = set(['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'un', 'una', 'con', 'es', 'del', 'por', 'se', 'las', 'más', 'su', 'sus', 'no', 'para', 'como', 'tras', 'tras', 'entre', 'sobre', 'al'])

# 4. Conteo de Palabras
from collections import Counter
conteo_palabras = Counter(p for p in palabras if p not in stopwords_es and len(p) > 3)

print("--- Top 10 Palabras Clave en Comentarios Gen Z ---\n", conteo_palabras.most_common(10))
# Out:
# --- Top 10 Palabras Clave en Comentarios Gen Z ---
#  [('jóvenes', 15), ('protestas', 13), ('protesta', 9), ('juvenil', 7), ('calle', 7), ('movimiento', 7), ('política', 6), ('digital', 6), ('falta', 6), ('real', 6)]

# %%
# Celda 6: Top Palabras Clave (Frankenstein)
texto_frank = ' '.join(df[df['Categoria'] == 'Frankenstein']['Comentario_Reaccion'].astype(str) + ' ' +
                       df[df['Categoria'] == 'Frankenstein']['Resumen'].astype(str))

texto_limpio_frank = re.sub(r'[^\w\s]', '', texto_frank.lower())
palabras_frank = texto_limpio_frank.split()

# 4. Conteo de Palabras (usando las mismas stopwords)
conteo_palabras_frank = Counter(p for p in palabras_frank if p not in stopwords_es and len(p) > 3)

print("--- Top 10 Palabras Clave en Comentarios Frankenstein ---\n", conteo_palabras_frank.most_common(10))
# Out:
# --- Top 10 Palabras Clave en Comentarios Frankenstein ---
#  [('película', 25), ('director', 23), ('toro', 17), ('monstruo', 17), ('historia', 12), ('actor', 11), ('análisis', 8), ('streaming', 6), ('pero', 6), ('final', 6)]

# %% [markdown]
# ### Análisis de Sentimiento/Tono (Simulado) (Celda 7)
# Dado que no tenemos datos de sentimiento real, crearemos un indicador de Positivismo/Negativismo simulado basado en palabras clave para cada categoría

# %%
# Celda 7 (REVISADA Y MEJORADA)

# Re-definir diccionarios (puedes añadir más sinónimos si lo deseas)
sentimiento_genz = {
    'Positivo': ['esperanza', 'cambio', 'unidos', 'apoyo', 'futuro', 'despierta'],
    'Negativo': ['represion', 'violencia', 'detenidos', 'inseguridad', 'vandalismo', 'abusos'] # Sin tildes para evitar problemas
}

sentimiento_frank = {
    'Positivo': ['obra maestra', 'emocion', 'oscar', 'aplausos', 'genio', 'increible', 'joya', 'adoracion'],
    'Negativo': ['oscura', 'tragedia', 'dolor', 'miedo', 'controversia', 'tortuoso', 'nihilista', 'abandono']
}

def calcular_tono(texto, diccionario):
    """Calcula un puntaje de tono basado en la presencia de frases clave."""
    if pd.isna(texto):
        return 0
    
    # 1. Limpieza: Remover puntuación (excepto espacios) y convertir a minúsculas
    texto_limpio = re.sub(r'[^\w\s]', '', str(texto).lower())
    
    puntaje = 0
    # 2. Iterar sobre las palabras positivas y usar .count() para contarlas
    for palabra in diccionario['Positivo']:
        puntaje += texto_limpio.count(palabra)
        
    # 3. Iterar sobre las palabras negativas y restar el conteo
    for palabra in diccionario['Negativo']:
        puntaje -= texto_limpio.count(palabra)
        
    return puntaje

# 2. Aplicar la función a las categorías (EL CÓDIGO DE APLICACIÓN ES CORRECTO)
df['Tono_Sentimiento'] = 0

# Generacion Z
mask_genz = df['Categoria'] == 'Generacion Z'
df.loc[mask_genz, 'Tono_Sentimiento'] = (
    df.loc[mask_genz, 'Resumen'].astype(str) + ' ' + df.loc[mask_genz, 'Comentario_Reaccion'].astype(str)
).apply(lambda x: calcular_tono(x, sentimiento_genz))

# Frankenstein
mask_frank = df['Categoria'] == 'Frankenstein'
df.loc[mask_frank, 'Tono_Sentimiento'] = (
    df.loc[mask_frank, 'Resumen'].astype(str) + ' ' + df.loc[mask_frank, 'Comentario_Reaccion'].astype(str)
).apply(lambda x: calcular_tono(x, sentimiento_frank))

# 3. Visualización y Resumen (Continúa igual)


# 3. Visualización del Tono por Categoría 
plt.figure(figsize=(8, 6))
sns.boxplot(x='Categoria', y='Tono_Sentimiento', data=df)
plt.title('Distribución Simulada del Tono de Sentimiento por Tema')
plt.xlabel('Tema')
plt.ylabel('Puntaje de Tono (Positivo > 0, Negativo < 0)')
plt.show()

# Resumen numérico del tono
print("\n--- Tono Promedio y Desviación Estándar por Tema ---")
print(df.groupby('Categoria')['Tono_Sentimiento'].agg(['mean', 'std']))
# Out:
# --- Tono Promedio y Desviación Estándar por Tema ---
#               mean       std
# Categoria
# Frankenstein  0.00  0.492366
# Generacion Z  0.08  0.506124

# %%
# Celda 8: Cruce de datos (CORREGIDA)

# ----------------------------------------------------
# ----------------------------------------------------
df_genz = df[df['Categoria'] == 'Generacion Z'].copy() 
df_frank_copy = df[df['Categoria'] == 'Frankenstein'].copy()

# ----------------------------------------------------
# 2. Influencia del Director en el Tono de Frankenstein
# ----------------------------------------------------
df_frank_copy['Menciona_Director'] = df_frank_copy['Comentario_Reaccion'].str.contains('Del Toro|GDT', case=False, na=False)

tono_por_mencion = df_frank_copy.groupby('Menciona_Director')['Tono_Sentimiento'].mean().reset_index()
tono_por_mencion['Menciona_Director'] = tono_por_mencion['Menciona_Director'].replace({True: 'Menciona Director', False: 'No Menciona Director'})

print("\n--- Tono Promedio de Frankenstein al Mencionar al Director ---")
print(tono_por_mencion)

# ----------------------------------------------------
# 3. Plataformas Sociales Mencionadas en Registros Gen Z
# ----------------------------------------------------
df_genz['Menciona_Plataforma'] = 'Otros'
df_genz.loc[df_genz['Comentario_Reaccion'].str.contains('TikTok', case=False, na=False), 'Menciona_Plataforma'] = 'TikTok'
df_genz.loc[df_genz['Comentario_Reaccion'].str.contains('Twitter|X', case=False, na=False), 'Menciona_Plataforma'] = 'X/Twitter'
df_genz.loc[df_genz['Comentario_Reaccion'].str.contains('Instagram', case=False, na=False), 'Menciona_Plataforma'] = 'Instagram'

plt.figure(figsize=(8, 5))
sns.countplot(y='Menciona_Plataforma', data=df_genz[df_genz['Menciona_Plataforma'] != 'Otros'], order=df_genz['Menciona_Plataforma'].value_counts().index)
plt.title('Distribución de Plataformas Mencionadas en Comentarios Gen Z')
plt.xlabel('Conteo de Menciones')
plt.ylabel('Plataforma')
plt.show()
# Out:
# --- Tono Promedio de Frankenstein al Mencionar al Director ---
#       Menciona_Director  Tono_Sentimiento
# 0  No Menciona Director             0.025
# 1     Menciona Director            -0.100
